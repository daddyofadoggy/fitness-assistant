# %%
import pandas as pd

# %%
import minsearch

# %%
df = pd.read_csv('../data/data.csv')
df.shape
# Out:
# (207, 8)

# %%
df.head()
# Out:
#    id exercise_name   type_of_activity type_of_equipment   body_part  type  \
# 0   0      Push-Ups           Strength        Bodyweight  Upper Body  Push
# 1   1        Squats           Strength        Bodyweight  Lower Body  Push
# 2   2         Plank  Strength/Mobility        Bodyweight        Core  Hold
# 3   3      Deadlift           Strength           Barbell  Lower Body  Pull
# 4   4   Bicep Curls           Strength         Dumbbells  Upper Body  Pull
#
#                   muscle_groups_activated  \
# 0            Pectorals, Triceps, Deltoids
# 1          Quadriceps, Glutes, Hamstrings
# 2  Rectus Abdominis, Transverse Abdominis
# 3          Glutes, Hamstrings, Lower Back
# 4                        Biceps, Forearms
#
#                                         instructions
# 0  Start in a high plank position with your hands...
# 1  Stand with feet shoulder-width apart. Lower yo...
# 2  Start in a forearm plank position with your el...
# 3  Stand with feet hip-width apart, barbell in fr...
# 4  Stand with a dumbbell in each hand, arms fully...

# %%
df.columns
# Out:
# Index(['id', 'exercise_name', 'type_of_activity', 'type_of_equipment',
#        'body_part', 'type', 'muscle_groups_activated', 'instructions'],
#       dtype='object')

# %%
documents = df.to_dict(orient='records')

# %%
#documents
# Out:
# [{'id': 0,
#   'exercise_name': 'Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Start in a high plank position with your hands under your shoulders. Lower your body until your chest nearly touches the floor. Push back up to the starting position.'},
#  {'id': 1,
#   'exercise_name': 'Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand with feet shoulder-width apart. Lower your body as if sitting back into a chair, keeping your chest up. Return to standing.'},
#  {'id': 2,
#   'exercise_name': 'Plank',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Transverse Abdominis',
#   'instructions': 'Start in a forearm plank position with your elbows directly under your shoulders. Keep your body in a straight line from head to heels.'},
#  {'id': 3,
#   'exercise_name': 'Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet hip-width apart, barbell in front of you. Bend at the hips and knees to grasp the bar, then lift it by straightening your hips and knees.'},
#  {'id': 4,
#   'exercise_name': 'Bicep Curls',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with a dumbbell in each hand, arms fully extended. Curl the weights up to your shoulders while keeping your elbows close to your torso.'},
#  {'id': 5,
#   'exercise_name': 'Kettlebell Swing',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Stand with feet slightly wider than shoulder-width. Swing the kettlebell between your legs and then up to shoulder height by driving your hips forward.'},
#  {'id': 6,
#   'exercise_name': 'Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a dumbbell in each hand at shoulder height, then press them overhead until your arms are fully extended. Lower back to shoulder height.'},
#  {'id': 7,
#   'exercise_name': 'Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at the lat pulldown machine, grasp the bar with a wide grip, and pull it down to your chest. Slowly return to the starting position.'},
#  {'id': 8,
#   'exercise_name': 'Hamstring Stretch',
#   'type_of_activity': 'Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Stretch',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Stand upright and place one heel on a bench or step. Lean forward slightly to feel a stretch in the hamstring of the elevated leg.'},
#  {'id': 9,
#   'exercise_name': 'Jumping Jacks',
#   'type_of_activity': 'Cardio/Warm-up',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves, Deltoids, Glutes',
#   'instructions': 'Stand upright with feet together and arms at your sides. Jump your feet out while raising your arms overhead, then return to the starting position.'},
#  {'id': 10,
#   'exercise_name': 'Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie flat on a bench with a barbell. Lower the bar to your chest and push it back up to the starting position.'},
#  {'id': 11,
#   'exercise_name': 'Lunges',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step forward with one leg and lower your hips until both knees are bent at a 90-degree angle. Push back to the starting position.'},
#  {'id': 12,
#   'exercise_name': 'Pull-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grasp a pull-up bar with an overhand grip. Pull your body up until your chin is above the bar, then lower back down.'},
#  {'id': 13,
#   'exercise_name': 'Mountain Climbers',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors, Deltoids',
#   'instructions': 'Start in a plank position and alternate driving your knees towards your chest as quickly as possible.'},
#  {'id': 14,
#   'exercise_name': 'Leg Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with your legs extended. Lift your legs until they are perpendicular to the floor, then lower them back down.'},
#  {'id': 15,
#   'exercise_name': 'Tricep Dips',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps, Deltoids',
#   'instructions': 'Place your hands behind you on a bench or chair. Lower your body by bending your elbows, then push back up to the starting position.'},
#  {'id': 16,
#   'exercise_name': 'Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with your knees bent, lean back slightly, and twist your torso to each side, tapping the floor with your hands.'},
#  {'id': 17,
#   'exercise_name': 'Burpees',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Quadriceps, Core',
#   'instructions': 'Start in a standing position, drop into a squat, kick your feet back into a plank, return to the squat position, and jump up.'},
#  {'id': 18,
#   'exercise_name': 'Dumbbell Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'With a dumbbell in each hand, bend at the waist with your back straight. Pull the dumbbells towards your torso, then lower them back down.'},
#  {'id': 19,
#   'exercise_name': 'Goblet Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a kettlebell at chest level and squat down as if sitting in a chair. Return to standing.'},
#  {'id': 20,
#   'exercise_name': 'Glute Bridge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Lie on your back with knees bent and feet flat on the floor. Lift your hips until your body forms a straight line from shoulders to knees.'},
#  {'id': 21,
#   'exercise_name': 'Overhead Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Hold a dumbbell with both hands overhead, then lower it behind your head by bending your elbows. Extend your arms back to the starting position.'},
#  {'id': 22,
#   'exercise_name': 'Side Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Shoulders',
#   'instructions': 'Lie on one side with your legs straight. Lift your hips so your body forms a straight line, supporting yourself on one forearm.'},
#  {'id': 23,
#   'exercise_name': 'Cable Flyes',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. With a slight bend in your elbows, bring your hands together in front of your chest.'},
#  {'id': 24,
#   'exercise_name': 'Step-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes',
#   'instructions': 'Step onto a bench or box with one foot, then push through that foot to lift your body up. Step back down and repeat on the other side.'},
#  {'id': 25,
#   'exercise_name': 'Barbell Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet hip-width apart, bend forward at the hips, and row the barbell towards your torso. Lower it back down.'},
#  {'id': 26,
#   'exercise_name': 'Chest Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Press the weights straight up over your chest, then lower them back down.'},
#  {'id': 27,
#   'exercise_name': 'Box Jumps',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Stand in front of a sturdy box or bench. Jump onto the box, landing softly, then step back down.'},
#  {'id': 28,
#   'exercise_name': 'Hanging Leg Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Hang from a pull-up bar and raise your legs until they are parallel to the floor. Lower them back down slowly.'},
#  {'id': 29,
#   'exercise_name': "Farmer's Walk",
#   'type_of_activity': 'Strength/Cardio',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Full Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Forearms, Shoulders, Core',
#   'instructions': 'Hold a heavy dumbbell in each hand at your sides and walk forward while maintaining a straight posture.'},
#  {'id': 30,
#   'exercise_name': 'Calf Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves',
#   'instructions': 'Stand with the balls of your feet on the edge of a step. Raise your heels as high as possible, then lower them back down.'},
#  {'id': 31,
#   'exercise_name': 'Battle Ropes',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Ropes',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Forearms, Core',
#   'instructions': 'Hold the ends of the ropes in each hand. Alternate waves with your arms to move the ropes up and down as quickly as possible.'},
#  {'id': 32,
#   'exercise_name': 'Medicine Ball Slams',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lift a medicine ball overhead and slam it down on the ground with as much force as possible. Catch it on the rebound and repeat.'},
#  {'id': 33,
#   'exercise_name': 'Dumbbell Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet hip-width apart, holding a dumbbell in each hand. Bend at the hips and knees to lower the weights, then lift back up.'},
#  {'id': 34,
#   'exercise_name': 'Push Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a barbell at shoulder height. Use your legs to help press the bar overhead, then lower it back to the starting position.'},
#  {'id': 35,
#   'exercise_name': 'Treadmill Run',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Treadmill',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Hamstrings, Calves',
#   'instructions': 'Run on a treadmill at a speed and incline that challenges your endurance.'},
#  {'id': 36,
#   'exercise_name': 'Incline Dumbbell Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench with a dumbbell in each hand. Press the weights up and together over your chest, then lower them back down.'},
#  {'id': 37,
#   'exercise_name': 'Renegade Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps, Core',
#   'instructions': 'Start in a plank position with a dumbbell in each hand. Row one dumbbell towards your torso while balancing on the other hand.'},
#  {'id': 38,
#   'exercise_name': 'Leg Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Sit on a leg press machine with your feet shoulder-width apart on the platform. Push the platform away by extending your legs.'},
#  {'id': 39,
#   'exercise_name': 'Cable Tricep Pushdown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing a cable machine with a high pulley. Push the handle downwards until your arms are fully extended.'},
#  {'id': 40,
#   'exercise_name': 'Single-Leg Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Stand on one leg, holding a dumbbell in the opposite hand. Bend at the hips to lower the weight while extending the free leg behind you.'},
#  {'id': 41,
#   'exercise_name': 'Inverted Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Lie under a bar or suspension trainer, pull your chest towards the bar while keeping your body straight, then lower back down.'},
#  {'id': 42,
#   'exercise_name': 'Pallof Press',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Transverse Abdominis',
#   'instructions': 'Stand sideways to a cable machine with the handle at chest height. Push the handle straight out in front of you, resisting the rotation.'},
#  {'id': 43,
#   'exercise_name': 'Kettlebell Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet shoulder-width apart, kettlebell between your feet. Bend at the hips and knees to lift the kettlebell off the ground.'},
#  {'id': 44,
#   'exercise_name': 'Hanging Knee Tucks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Hang from a pull-up bar and tuck your knees towards your chest, then slowly lower them back down.'},
#  {'id': 45,
#   'exercise_name': 'Resistance Band Pull Aparts',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Hold a resistance band in front of you with arms extended. Pull the band apart by bringing your hands out to your sides.'},
#  {'id': 46,
#   'exercise_name': 'Bulgarian Split Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand lunge-style with one foot behind you on a bench. Lower your hips until your front thigh is parallel to the floor, then push back up.'},
#  {'id': 47,
#   'exercise_name': 'Seated Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a bench with a dumbbell in each hand at shoulder height. Press the weights overhead until your arms are fully extended.'},
#  {'id': 48,
#   'exercise_name': 'Incline Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Place your hands on an elevated surface like a bench. Lower your chest towards the surface, then push back up.'},
#  {'id': 49,
#   'exercise_name': 'Hip Thrusts',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Sit on the ground with your upper back against a bench, barbell across your hips. Lift your hips towards the ceiling by squeezing your glutes.'},
#  {'id': 50,
#   'exercise_name': 'Barbell Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with feet shoulder-width apart, holding a barbell with an underhand grip. Curl the bar towards your shoulders, then lower it back down.'},
#  {'id': 51,
#   'exercise_name': 'Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a cable row machine with feet braced. Pull the handle towards your torso, then slowly return to the starting position.'},
#  {'id': 52,
#   'exercise_name': 'Plank Shoulder Taps',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques, Deltoids',
#   'instructions': 'Start in a high plank position. Tap one hand to the opposite shoulder, then switch sides, while keeping your body stable.'},
#  {'id': 53,
#   'exercise_name': 'Dumbbell Lateral Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand with a dumbbell in each hand, arms at your sides. Raise your arms out to the sides until they are parallel to the floor.'},
#  {'id': 54,
#   'exercise_name': 'Wall Sit',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Quadriceps, Glutes',
#   'instructions': 'Lean against a wall with your feet shoulder-width apart. Slide down until your knees are at a 90-degree angle and hold the position.'},
#  {'id': 55,
#   'exercise_name': 'Spider Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques',
#   'instructions': 'Start in a forearm plank position. Bring one knee to the outside of your elbow, then return to the starting position and repeat on the other side.'},
#  {'id': 56,
#   'exercise_name': 'Sumo Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with a wide stance, toes pointing out. Grasp the barbell with hands inside your knees, and lift it by extending your hips and knees.'},
#  {'id': 57,
#   'exercise_name': 'Single Arm Dumbbell Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Place one knee and hand on a bench for support, row the dumbbell towards your torso with the other hand.'},
#  {'id': 58,
#   'exercise_name': 'Kettlebell Clean and Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Swing the kettlebell up to shoulder height, then press it overhead. Lower it back down and repeat.'},
#  {'id': 59,
#   'exercise_name': 'Jump Rope',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Jump Rope',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves, Shoulders',
#   'instructions': 'Jump over the rope as it passes under your feet, keeping a steady rhythm.'},
#  {'id': 60,
#   'exercise_name': 'Side Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Step out to the side, bending one knee while keeping the other leg straight. Push back to the starting position.'},
#  {'id': 61,
#   'exercise_name': 'Machine Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Sit at a chest fly machine, grasp the handles, and bring them together in front of your chest, then return to the starting position.'},
#  {'id': 62,
#   'exercise_name': 'Hack Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on a hack squat machine platform, lower your body by bending your knees, then push back up to the starting position.'},
#  {'id': 63,
#   'exercise_name': 'Decline Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Place your feet on an elevated surface, hands on the floor. Lower your chest towards the floor, then push back up.'},
#  {'id': 64,
#   'exercise_name': 'Band Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a resistance band to a high anchor. Pull the band towards your face, leading with your elbows.'},
#  {'id': 65,
#   'exercise_name': 'Ab Wheel Rollout',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Ab Wheel',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Kneel on the floor with an ab wheel in front of you. Roll the wheel forward while keeping your core tight, then roll back.'},
#  {'id': 66,
#   'exercise_name': 'Side Leg Raises',
#   'type_of_activity': 'Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Glutes, Hip Flexors',
#   'instructions': 'Lie on your side with legs straight. Lift your top leg towards the ceiling, then lower it back down.'},
#  {'id': 67,
#   'exercise_name': 'Romanian Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Hold a barbell in front of your thighs. Bend at the hips to lower the bar down your legs, then return to standing.'},
#  {'id': 68,
#   'exercise_name': 'Arnold Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold dumbbells at shoulder height, palms facing you. Rotate your arms as you press the weights overhead, ending with palms facing forward.'},
#  {'id': 69,
#   'exercise_name': 'Landmine Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Deltoids, Triceps',
#   'instructions': 'Hold the end of a barbell anchored in a landmine attachment. Press the bar overhead with one arm.'},
#  {'id': 70,
#   'exercise_name': 'Tuck Jumps',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Jump straight up and tuck your knees towards your chest, then land softly and repeat.'},
#  {'id': 71,
#   'exercise_name': 'Windshield Wipers',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Rotate your legs side to side like windshield wipers.'},
#  {'id': 72,
#   'exercise_name': 'Dumbbell Shrugs',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Trapezius',
#   'instructions': 'Stand with a dumbbell in each hand at your sides. Shrug your shoulders towards your ears, then lower them back down.'},
#  {'id': 73,
#   'exercise_name': 'Sled Push',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sled',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Shoulders',
#   'instructions': 'Push a weighted sled across a flat surface, keeping your back straight and core tight.'},
#  {'id': 74,
#   'exercise_name': 'Cable Bicep Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand facing a cable machine with the handle attached to a low pulley. Curl the handle towards your shoulders, then lower it back down.'},
#  {'id': 75,
#   'exercise_name': 'Dumbbell Kickback',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Bend at the waist with a dumbbell in each hand. Extend your arms straight back, then return to the starting position.'},
#  {'id': 76,
#   'exercise_name': 'Flutter Kicks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with legs extended. Lift your feet off the ground and alternate kicking them up and down.'},
#  {'id': 77,
#   'exercise_name': 'High Knees',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Hip Flexors, Calves',
#   'instructions': 'Run in place while driving your knees towards your chest as high as possible.'},
#  {'id': 78,
#   'exercise_name': 'Sledgehammer Slams',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sledgehammer',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lift a sledgehammer overhead and slam it down onto a tire or other soft surface.'},
#  {'id': 79,
#   'exercise_name': 'Lateral Step-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step up onto a bench or box laterally with one foot, then bring the other foot up to meet it. Step back down and repeat.'},
#  {'id': 80,
#   'exercise_name': 'Cable Chest Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Stand in front of a cable machine with handles at chest height. Press the handles forward, then return to the starting position.'},
#  {'id': 81,
#   'exercise_name': 'TRX Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'TRX',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grip the TRX handles and lean back, keeping your body straight. Pull your chest towards the handles, then lower back down.'},
#  {'id': 82,
#   'exercise_name': 'Medicine Ball Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with knees bent, holding a medicine ball. Twist your torso to each side, tapping the ball on the floor.'},
#  {'id': 83,
#   'exercise_name': 'Pendlay Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Bend over with a barbell on the floor. Row the barbell to your torso, then lower it back to the floor each rep.'},
#  {'id': 84,
#   'exercise_name': 'Side Plank with Leg Lift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Glutes, Shoulders',
#   'instructions': 'In a side plank position, lift your top leg towards the ceiling, then lower it back down.'},
#  {'id': 85,
#   'exercise_name': 'Hip Abduction',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hip Flexors',
#   'instructions': 'Sit on a hip abduction machine and press your legs apart against the resistance, then return to the starting position.'},
#  {'id': 86,
#   'exercise_name': 'Dumbbell Front Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand with a dumbbell in each hand, palms facing your thighs. Raise your arms in front of you until they are parallel to the floor.'},
#  {'id': 87,
#   'exercise_name': 'Chin-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grip a pull-up bar with an underhand grip. Pull your body up until your chin is above the bar, then lower back down.'},
#  {'id': 88,
#   'exercise_name': 'Box Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand in front of a box with a barbell on your shoulders. Squat down until you sit on the box, then stand back up.'},
#  {'id': 89,
#   'exercise_name': 'Battle Rope Waves',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Ropes',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Forearms, Core',
#   'instructions': 'Hold the ends of the ropes and create waves by alternating your arms up and down rapidly.'},
#  {'id': 90,
#   'exercise_name': 'Zercher Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a barbell in the crook of your elbows. Squat down until your thighs are parallel to the floor, then push back up.'},
#  {'id': 91,
#   'exercise_name': 'Walking Lunges',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step forward into a lunge, then bring your back foot forward to step into the next lunge.'},
#  {'id': 92,
#   'exercise_name': 'Kettlebell Snatch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Swing a kettlebell between your legs, then pull it overhead in one motion.'},
#  {'id': 93,
#   'exercise_name': 'Single-Leg Glute Bridge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Lie on your back with one foot on the ground and the other leg extended. Lift your hips towards the ceiling.'},
#  {'id': 94,
#   'exercise_name': 'TRX Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'TRX',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Perform push-ups with your hands in the TRX handles, keeping your body straight.'},
#  {'id': 95,
#   'exercise_name': 'Machine Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Sit on a leg curl machine and curl the pad down towards your glutes, then return to the starting position.'},
#  {'id': 96,
#   'exercise_name': 'Incline Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench with a barbell. Press the bar up and together over your chest, then lower it back down.'},
#  {'id': 97,
#   'exercise_name': 'Resistance Band Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand on a resistance band with feet shoulder-width apart. Bend at the hips and knees to lift the band off the ground.'},
#  {'id': 98,
#   'exercise_name': 'Decline Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a decline bench with a barbell. Lower the bar to your chest, then press it back up.'},
#  {'id': 99,
#   'exercise_name': 'Dumbbell Step-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step onto a bench with one foot while holding dumbbells, then bring the other foot up to meet it.'},
#  {'id': 100,
#   'exercise_name': 'Cable Lateral Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand next to a cable machine with the handle at the low pulley. Raise your arm out to the side until it is parallel to the floor.'},
#  {'id': 101,
#   'exercise_name': 'Reverse Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step backward into a lunge, lowering your hips until both knees are at a 90-degree angle.'},
#  {'id': 102,
#   'exercise_name': 'Toe Touches',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Reach your hands towards your toes.'},
#  {'id': 103,
#   'exercise_name': 'Machine Leg Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps',
#   'instructions': 'Sit on a leg extension machine and extend your legs until they are straight, then return to the starting position.'},
#  {'id': 104,
#   'exercise_name': 'Dumbbell Pullover',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Pectorals, Triceps',
#   'instructions': 'Lie on a bench holding a dumbbell over your chest. Lower the weight behind your head, then pull it back up.'},
#  {'id': 105,
#   'exercise_name': 'Barbell Shrug',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Trapezius',
#   'instructions': 'Stand with feet shoulder-width apart, holding a barbell. Shrug your shoulders towards your ears, then lower them back down.'},
#  {'id': 106,
#   'exercise_name': 'T-Bar Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet shoulder-width apart, holding a T-bar. Row the weight towards your torso, then lower it back down.'},
#  {'id': 107,
#   'exercise_name': 'Bulgarian Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Stand on one leg holding a dumbbell in each hand. Bend at the hips to lower the weights, then lift back up.'},
#  {'id': 108,
#   'exercise_name': 'Pistol Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg with the other leg extended in front of you. Lower your hips until your thigh is parallel to the floor, then push back up.'},
#  {'id': 109,
#   'exercise_name': 'Seated Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Sit on a leg curl machine and curl the pad down towards your glutes, then return to the starting position.'},
#  {'id': 110,
#   'exercise_name': 'Russian Kettlebell Swing',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Swing the kettlebell between your legs and up to shoulder height, driving the movement with your hips.'},
#  {'id': 111,
#   'exercise_name': 'Incline Dumbbell Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Sit on an incline bench with a dumbbell in each hand. Curl the weights up towards your shoulders, then lower them back down.'},
#  {'id': 112,
#   'exercise_name': 'Decline Sit-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on a decline bench and sit up, bringing your chest towards your knees.'},
#  {'id': 113,
#   'exercise_name': 'Side Plank Dips',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Shoulders',
#   'instructions': 'Start in a side plank position. Lower your hips towards the floor, then lift them back up.'},
#  {'id': 114,
#   'exercise_name': 'Single Arm Kettlebell Swing',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Swing the kettlebell between your legs and up to shoulder height with one hand, driving the movement with your hips.'},
#  {'id': 115,
#   'exercise_name': 'Jumping Squats',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Lower into a squat, then explode upwards into a jump. Land softly and repeat.'},
#  {'id': 116,
#   'exercise_name': 'Cable Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. Bring the handles together in front of your chest, then return to the starting position.'},
#  {'id': 117,
#   'exercise_name': 'Dumbbell Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Hold a dumbbell with both hands overhead, then lower it behind your head by bending your elbows. Extend your arms back to the starting position.'},
#  {'id': 118,
#   'exercise_name': 'Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Lie face down on a leg curl machine and curl the pad towards your glutes, then return to the starting position.'},
#  {'id': 119,
#   'exercise_name': 'One-Arm Push-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Start in a push-up position with one hand behind your back. Lower your body until your chest nearly touches the floor, then push back up.'},
#  {'id': 120,
#   'exercise_name': 'Machine Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a shoulder press machine, grasp the handles, and press them overhead until your arms are fully extended.'},
#  {'id': 121,
#   'exercise_name': 'Sumo Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand with feet wider than shoulder-width apart, toes pointing out. Lower your hips until your thighs are parallel to the floor, then push back up.'},
#  {'id': 122,
#   'exercise_name': 'Resistance Band Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on a resistance band with feet shoulder-width apart. Squat down while holding the band at shoulder height.'},
#  {'id': 123,
#   'exercise_name': 'One-Legged Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg with the other leg extended in front of you. Lower your hips until your thigh is parallel to the floor, then push back up.'},
#  {'id': 124,
#   'exercise_name': 'Landmine Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Place one end of a barbell in a landmine attachment. Row the other end towards your torso with both hands, then lower it back down.'},
#  {'id': 125,
#   'exercise_name': 'Superman Exercise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Lower Back, Glutes, Hamstrings',
#   'instructions': 'Lie face down on the floor with arms extended. Lift your arms, chest, and legs off the ground simultaneously, then lower them back down.'},
#  {'id': 126,
#   'exercise_name': 'Dumbbell Flyes',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Lower the weights out to the sides of your chest, then bring them back together over your chest.'},
#  {'id': 127,
#   'exercise_name': 'Reverse Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Stand with feet hip-width apart, bend forward at the hips, and raise the dumbbells out to the sides until they are parallel to the floor.'},
#  {'id': 128,
#   'exercise_name': 'Cable Kickbacks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Attach an ankle strap to a low cable pulley. Kick your leg back while keeping your knee slightly bent, then return to the starting position.'},
#  {'id': 129,
#   'exercise_name': 'Kettlebell Push Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a kettlebell at shoulder height. Use your legs to help press the kettlebell overhead, then lower it back down.'},
#  {'id': 130,
#   'exercise_name': 'Dead Bug',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with arms extended towards the ceiling. Lower opposite arm and leg towards the floor while keeping your back flat.'},
#  {'id': 131,
#   'exercise_name': 'Smith Machine Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
# ...
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Lie face down on a leg curl machine and curl the pad towards your glutes, then return to the starting position.'},
#  {'id': 165,
#   'exercise_name': 'Seated Dumbbell Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a bench with a dumbbell in each hand at shoulder height. Press the weights overhead until your arms are fully extended.'},
#  {'id': 166,
#   'exercise_name': 'Weighted Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques, Shoulders',
#   'instructions': 'Start in a forearm plank position with a weight plate on your back. Hold the position while keeping your body straight.'},
#  {'id': 167,
#   'exercise_name': 'Step Mill',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings, Calves',
#   'instructions': 'Step continuously on a revolving staircase, keeping a steady pace.'},
#  {'id': 168,
#   'exercise_name': 'Standing Resistance Band Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Attach a resistance band to a sturdy anchor. Pull the handles towards your torso, keeping your elbows close to your body.'},
#  {'id': 169,
#   'exercise_name': 'Dumbbell Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a dumbbell in each hand and step forward into a lunge. Push back to the starting position and repeat on the other leg.'},
#  {'id': 170,
#   'exercise_name': 'Reverse Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with feet shoulder-width apart, holding a dumbbell in each hand with an overhand grip. Curl the weights up towards your shoulders.'},
#  {'id': 171,
#   'exercise_name': 'Banded Pull-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Loop a resistance band around a pull-up bar and place your knees in the band. Pull your body up until your chin is above the bar.'},
#  {'id': 172,
#   'exercise_name': 'Cable Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a rope handle to a high cable pulley. Pull the handle towards your face, leading with your elbows.'},
#  {'id': 173,
#   'exercise_name': 'Turkish Get-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lie on your back holding a kettlebell overhead. Stand up while keeping the kettlebell above your head, then return to lying.'},
#  {'id': 174,
#   'exercise_name': 'Weighted Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with knees bent, holding a medicine ball. Twist your torso to each side, tapping the ball on the floor.'},
#  {'id': 175,
#   'exercise_name': 'Cable Front Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand facing a cable machine with the handle at the low pulley. Raise the handle in front of you until your arm is parallel to the floor.'},
#  {'id': 176,
#   'exercise_name': 'Reverse Crunch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Lift your hips off the ground, bringing your knees towards your chest.'},
#  {'id': 177,
#   'exercise_name': 'Cable Tricep Kickback',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing a cable machine with a handle attached to the low pulley. Extend your arm straight back, then return to the starting position.'},
#  {'id': 178,
#   'exercise_name': 'Copenhagen Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Adductors',
#   'instructions': 'Lie on your side with your top leg on a bench and your bottom leg extended. Lift your hips to form a straight line from head to heels.'},
#  {'id': 179,
#   'exercise_name': 'Smith Machine Incline Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench under a Smith machine bar. Press the bar up and together over your chest, then lower it back down.'},
#  {'id': 180,
#   'exercise_name': 'Cable Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine, grasp the bar with a wide grip, and pull it down to your chest. Slowly return to the starting position.'},
#  {'id': 181,
#   'exercise_name': 'Cable Side Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Attach a handle to a low pulley and stand to the side of the cable machine. Step out into a side lunge, then return to the starting position.'},
#  {'id': 182,
#   'exercise_name': 'Dumbbell Bent-Over Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet shoulder-width apart, bend forward at the hips, and row the dumbbells towards your torso.'},
#  {'id': 183,
#   'exercise_name': 'Lateral Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Step out to the side, bending one knee while keeping the other leg straight. Push back to the starting position.'},
#  {'id': 184,
#   'exercise_name': 'Seated Machine Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a rowing machine with feet braced. Pull the handles towards your torso, then slowly return to the starting position.'},
#  {'id': 185,
#   'exercise_name': 'Decline Russian Twist',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on a decline bench with your knees bent. Twist your torso to each side, tapping your hands on the floor.'},
#  {'id': 186,
#   'exercise_name': 'Deadlift High Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Full Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Start with a barbell on the ground, perform a deadlift, and as you stand up, pull the barbell up towards your chest.'},
#  {'id': 187,
#   'exercise_name': 'Reverse Grip Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine with a reverse grip. Pull the bar down to your chest, then slowly return to the starting position.'},
#  {'id': 188,
#   'exercise_name': 'Cable Lateral Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Attach a handle to a low pulley and stand to the side of the cable machine. Step out into a side lunge, then return to the starting position.'},
#  {'id': 189,
#   'exercise_name': 'Pike Push-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Start in a downward dog position with your hips raised. Lower your head towards the floor, then push back up.'},
#  {'id': 190,
#   'exercise_name': 'One-Arm Dumbbell Snatch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Start with a dumbbell between your feet. Explosively pull the dumbbell up and overhead in one motion.'},
#  {'id': 191,
#   'exercise_name': 'Cable Front Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Attach a rope handle to a low pulley and stand facing the cable machine. Squat down while holding the rope at chest height.'},
#  {'id': 192,
#   'exercise_name': 'Tire Flip',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Tire',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Quadriceps, Hamstrings, Shoulders',
#   'instructions': 'Squat down and grab the edge of a tire. Lift the tire and flip it forward.'},
#  {'id': 193,
#   'exercise_name': 'Smith Machine Calf Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves',
#   'instructions': 'Stand under the bar of a Smith machine with the balls of your feet on a step. Raise your heels as high as possible, then lower them back down.'},
#  {'id': 194,
#   'exercise_name': 'Pistol Squat to Box',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg in front of a box. Lower your hips until you sit on the box, then stand back up.'},
#  {'id': 195,
#   'exercise_name': 'Standing Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Deltoids',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. Bring the handles together in front of your chest, then return to the starting position.'},
#  {'id': 196,
#   'exercise_name': 'Sled Drag',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sled',
#   'body_part': 'Full Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Quadriceps, Hamstrings, Shoulders',
#   'instructions': 'Attach a harness to a sled and drag it across a flat surface, walking or running backwards.'},
#  {'id': 197,
#   'exercise_name': 'Cable Hammer Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand facing a cable machine with the handle attached to the low pulley. Curl the handle towards your shoulders with a neutral grip.'},
#  {'id': 198,
#   'exercise_name': 'Cable Tricep Overhead Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing away from a cable machine with the handle attached to the low pulley. Extend the handle overhead until your arms are fully extended.'},
#  {'id': 199,
#   'exercise_name': 'Seated Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a cable row machine with feet braced. Pull the handle towards your torso, then slowly return to the starting position.'},
#  {'id': 200,
#   'exercise_name': 'Lying Dumbbell Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Lower the weights towards your head by bending your elbows, then extend your arms back to the starting position.'},
#  {'id': 201,
#   'exercise_name': 'Weighted Pull-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight/Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Hang a weight from your waist and perform a pull-up, bringing your chin above the bar.'},
#  {'id': 202,
#   'exercise_name': 'Incline Dumbbell Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Lie face down on an incline bench with a dumbbell in each hand. Row the weights towards your torso, then lower them back down.'},
#  {'id': 203,
#   'exercise_name': 'Machine Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine with a wide grip. Pull the bar down to your chest, then slowly return to the starting position.'},
#  {'id': 204,
#   'exercise_name': 'One-Arm Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand facing a cable machine with the handle attached to the low pulley. Row the handle towards your torso with one hand.'},
#  {'id': 205,
#   'exercise_name': 'Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a rope handle to a high cable pulley. Pull the handle towards your face, leading with your elbows.'},
#  {'id': 206,
#   'exercise_name': 'Dumbbell Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Press the weights up and together over your chest, then lower them back down.'}]

# %%
index = minsearch.Index(text_fields=['exercise_name', 'type_of_activity', 'type_of_equipment',
       'body_part', 'type', 'muscle_groups_activated', 'instructions'],
                        keyword_fields=[])

# %%
index.fit(documents)

# %% [markdown]
# ## RAG flow ##

# %%
import os

# %%
#os.environ['OPENAI_API_KEY'] = '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'

# %%
from openai import OpenAI
client = OpenAI()

# %%
def search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
#search('glutes')

# %%
prompt_template = """
You're a fitness insrtuctor. Answer the QUESTION based on the CONTEXT from our exercises database.
Use only the facts from the CONTEXT when answering the QUESTION.

QUESTION: {question}

CONTEXT:
{context}
""".strip()

entry_template = """
exercise_name: {exercise_name}
type_of_activity: {type_of_activity}
type_of_equipment: {type_of_equipment}
body_part: {body_part}
type: {type}
muscle_groups_activated: {muscle_groups_activated}
instructions: {instructions}
""".strip()

def build_prompt(query, search_results):
    context = ""
    
    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt, model='gpt-4o-mini'):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def rag(query, model='gpt-4o-mini'):
    search_results = search(query)
    prompt = build_prompt(query, search_results)
    #print(prompt)
    answer = llm(prompt, model=model)
    return answer

# %%
question = 'Is the Lat Pulldown considered a strength training activity, and if so, why?'
answer = rag(question)
print(answer)
# Out:
# Yes, the Lat Pulldown is considered a strength training activity. This classification is due to its focus on building strength in the upper body, specifically targeting the Latissimus Dorsi and Biceps muscles. The exercise utilizes a machine, which allows for resistance training as the user pulls the bar down, thereby enhancing muscular strength and endurance.

# %%
question = 'I want some core exercise to help my back'
answer = rag(question)
print(answer)
# Out:
# To help strengthen your back through core exercises, you can try the following:
#
# 1. **Superman Exercise**
#    - **Type of Activity**: Strength
#    - **Muscle Groups Activated**: Lower Back, Glutes, Hamstrings
#    - **Instructions**: Lie face down on the floor with arms extended. Lift your arms, chest, and legs off the ground simultaneously, then lower them back down.
#
# 2. **Dead Bug**
#    - **Type of Activity**: Strength
#    - **Muscle Groups Activated**: Rectus Abdominis, Hip Flexors
#    - **Instructions**: Lie on your back with arms extended towards the ceiling. Lower opposite arm and leg towards the floor while keeping your back flat.
#
# These exercises will not only engage your core but also support and strengthen your back.

# %%
question = 'I want some core calisthenics exercise to help my back'
answer = rag(question)
print(answer)
# Out:
# Here are some core calisthenics exercises that can help strengthen your back:
#
# 1. **Superman Exercise**
#    - **Type of Activity:** Strength
#    - **Equipment:** Bodyweight
#    - **Muscle Groups Activated:** Lower Back, Glutes, Hamstrings
#    - **Instructions:** Lie face down on the floor with arms extended. Lift your arms, chest, and legs off the ground simultaneously, then lower them back down.
#
# 2. **Dead Bug**
#    - **Type of Activity:** Strength
#    - **Equipment:** Bodyweight
#    - **Muscle Groups Activated:** Rectus Abdominis, Hip Flexors
#    - **Instructions:** Lie on your back with arms extended towards the ceiling. Lower opposite arm and leg towards the floor while keeping your back flat.
#
# 3. **Hanging Leg Raises**
#    - **Type of Activity:** Strength
#    - **Equipment:** Bodyweight
#    - **Muscle Groups Activated:** Rectus Abdominis, Hip Flexors
#    - **Instructions:** Hang from a pull-up bar and raise your legs until they are parallel to the floor. Lower them back down slowly.
#
# Incorporating these exercises into your routine can help enhance core stability and support your back.

# %% [markdown]
# ## Retrival Evaluation ##

# %%
df_question = pd.read_csv('../data/ground-truth-retrieval.csv')

# %%
df_question.head(10)
# Out:
#    id                                           question
# 0   0        What is the starting position for push-ups?
# 1   0  Which muscle groups are targeted during push-ups?
# 2   0       Do I need any equipment to perform push-ups?
# 3   0  How do I properly lower my body during a push-up?
# 4   0  What type of exercise are push-ups classified as?
# 5   1  What body position should I maintain during sq...
# 6   1  Which muscle groups are activated when perform...
# 7   1         Do I need any equipment to perform squats?
# 8   1  How should my feet be positioned while doing s...
# 9   1  What is the proper motion for lowering my body...

# %%
ground_truth = df_question.to_dict(orient='records')

# %%
ground_truth[0]
# Out:
# {'id': 0, 'question': 'What is the starting position for push-ups?'}

# %%
def hit_rate(relevance_total):
    cnt = 0

    for line in relevance_total:
        if True in line:
            cnt = cnt + 1

    return cnt / len(relevance_total)

def mrr(relevance_total):
    total_score = 0.0

    for line in relevance_total:
        for rank in range(len(line)):
            if line[rank] == True:
                total_score = total_score + 1 / (rank + 1)

    return total_score / len(relevance_total)

# %%
def minsearch_search(query):
    boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
def evaluate(ground_truth, search_function):
    relevance_total = []

    for q in tqdm(ground_truth):
        doc_id = q['id']
        results = search_function(q)
        relevance = [d['id'] == doc_id for d in results]
        relevance_total.append(relevance)

    return {
        'hit_rate': hit_rate(relevance_total),
        'mrr': mrr(relevance_total),
    }

# %%
from tqdm.auto import tqdm

# %%
evaluate(ground_truth, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/1035 [00:00<?, ?it/s]
# {'hit_rate': 0.9391304347826087, 'mrr': 0.8264063338701019}

# %% [markdown]
# ## Finding the best parameters ##

# %%
df_validation = df_question[:100]
df_test = df_question[100:]

# %%
df_validation.head()
# Out:
#    id                                           question
# 0   0        What is the starting position for push-ups?
# 1   0  Which muscle groups are targeted during push-ups?
# 2   0       Do I need any equipment to perform push-ups?
# 3   0  How do I properly lower my body during a push-up?
# 4   0  What type of exercise are push-ups classified as?

# %%
import random

def simple_optimize(param_ranges, objective_function, n_iterations=10):
    best_params = None
    best_score = float('-inf')  # Assuming we're minimizing. Use float('-inf') if maximizing.

    for _ in range(n_iterations):
        # Generate random parameters
        current_params = {}
        for param, (min_val, max_val) in param_ranges.items():
            if isinstance(min_val, int) and isinstance(max_val, int):
                current_params[param] = random.randint(min_val, max_val)
            else:
                current_params[param] = random.uniform(min_val, max_val)
        
        # Evaluate the objective function
        current_score = objective_function(current_params)
        
        # Update best if current is better
        if current_score > best_score:  # Change to > if maximizing
            best_score = current_score
            best_params = current_params
    
    return best_params, best_score

# %%
gt_val = df_validation.to_dict(orient='records')

# %%
def minsearch_search(query, boost=None):
    if boost is None:
        boost = {}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
param_ranges = {
    'exercise_name': (0.0, 3.0),
    'type_of_activity': (0.0, 3.0),
    'type_of_equipment': (0.0, 3.0),
    'body_part': (0.0, 3.0),
    'type': (0.0, 3.0),
    'muscle_groups_activated': (0.0, 3.0),
    'instructions': (0.0, 3.0),
}

# %%
evaluate(gt_val, lambda q: minsearch_search(q['question']))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'hit_rate': 0.94, 'mrr': 0.7970119047619048}

# %%
def objective(boosting_parameter):
    def search_function(q):
        return minsearch_search(q['question'], boosting_parameter)
    results = evaluate(gt_val, search_function)
    return results['mrr']

# %%
simple_optimize(param_ranges, objective, n_iterations=20 )
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# ({'exercise_name': 2.452138963655172,
#   'type_of_activity': 0.0945815257416881,
#   'type_of_equipment': 0.8425326046764732,
#   'body_part': 2.0368138833148777,
#   'type': 1.1566684186139289,
#   'muscle_groups_activated': 0.3188239377113703,
#   'instructions': 0.5591269022107551},
#  0.8959166666666667)

# %%
def minsearch_search_improved(query):
    boost = {
        'exercise_name': 2.452138963655172,
        'type_of_activity': 0.0945815257416881,
        'type_of_equipment': 0.8425326046764732,
        'body_part': 2.0368138833148777,
        'type': 1.1566684186139289,
        'muscle_groups_activated': 0.3188239377113703,
        'instructions': 0.5591269022107551}

    results = index.search(
        query=query,
        filter_dict={},
        boost_dict=boost,
        num_results=10
    )

    return results

# %%
evaluate(ground_truth, lambda q: minsearch_search_improved(q['question']))
# Out:
#   0%|          | 0/1035 [00:00<?, ?it/s]
# {'hit_rate': 0.9439613526570049, 'mrr': 0.9107326892109502}

# %% [markdown]
# ## RAG Evaluation ##

# %%
prompt2_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer to the given question.
Based on the relevance of the generated answer, you will classify it
as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the question
and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %%
ground_truth = df_question.to_dict(orient='records')

# %%
sample = ground_truth[0]
question = sample['question']
answer_llm = rag(question)

# %%
sample
# Out:
# {'id': 0, 'question': 'What is the starting position for push-ups?'}

# %%
question
# Out:
# 'What is the starting position for push-ups?'

# %%
answer_llm
# Out:
# 'The starting position for push-ups is to begin in a high plank position with your hands under your shoulders.'

# %%
prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )
print(prompt)
# Out:
# You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
# Your task is to analyze the relevance of the generated answer to the given question.
# Based on the relevance of the generated answer, you will classify it
# as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".
#
# Here is the data for evaluation:
#
# Question: What is the starting position for push-ups?
# Generated Answer: The starting position for push-ups is to begin in a high plank position with your hands under your shoulders.
#
# Please analyze the content and context of the generated answer in relation to the question
# and provide your evaluation in parsable JSON without using code blocks:
#
# {
#   "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
#   "Explanation": "[Provide a brief explanation for your evaluation]"
# }

# %%
evaluation = llm(prompt)

# %%
print(evaluation)
# Out:
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately describes the starting position for push-ups, detailing the high plank position and the placement of the hands, which directly addresses the question asked."
# }

# %%
import json
evaluations = []
df_sample = df_question.sample(n=100, random_state=1)
sample = df_sample.to_dict(orient='records')

for rec in tqdm(sample):
    question = rec['question']
    answer_llm = rag(question) 
    doc_id = rec['id']  
    prompt = prompt2_template.format(
        question=question,
        answer_llm=answer_llm
    )

    evaluation = llm(prompt)
    evaluation = json.loads(evaluation)

    evaluations.append((rec, answer_llm, evaluation))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#evaluations
# Out:
# [({'id': 171,
#    'question': 'What is the primary muscle group targeted by the Banded Pull-Up exercise?'},
#   'The primary muscle group targeted by the Banded Pull-Up exercise is the Latissimus Dorsi.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by correctly identifying the primary muscle group targeted by the Banded Pull-Up exercise, which is the Latissimus Dorsi. This clear and accurate response fulfills the information request made in the question.'}),
#  ({'id': 115, 'question': 'Is any equipment needed for jumping squats?'},
#   'No equipment is needed for jumping squats, as they are performed using bodyweight.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about whether any equipment is needed for jumping squats by stating that no equipment is required and that the exercise is performed using bodyweight, which is accurate and informative.'}),
#  ({'id': 53,
#    'question': 'Can you describe the proper form for performing a Dumbbell Lateral Raise?'},
#   'To perform a Dumbbell Lateral Raise with proper form, follow these instructions:\n\n1. Stand with a dumbbell in each hand, allowing your arms to hang down at your sides.\n2. Keep your back straight and core engaged.\n3. Raise your arms out to the sides until they are parallel to the floor.\n4. Maintain a slight bend in your elbows throughout the movement.\n5. Lower your arms back to the starting position with controlled motion.\n\nThis exercise targets the deltoid muscles in the upper body.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides a clear and detailed description of the proper form for performing a Dumbbell Lateral Raise, directly addressing the question asked. It includes step-by-step instructions and relevant details about technique, which are essential for understanding how to perform the exercise correctly.'}),
#  ({'id': 198,
#    'question': 'What equipment do I need to perform the Cable Tricep Overhead Extension?'},
#   'To perform the Cable Tricep Overhead Extension, you need a Cable Machine.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': "The generated answer mentions a Cable Machine, which is relevant equipment for performing the Cable Tricep Overhead Extension. However, it lacks details about other potential equipment or setup specifics that could enhance the response's completeness and relevance to the question."}),
#  ({'id': 19,
#    'question': 'Which part of the body does Goblet Squats primarily target?'},
#   'Goblet Squats primarily target the lower body, specifically activating the quadriceps, glutes, and hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the primary body parts targeted by Goblet Squats, specifically naming the quadriceps, glutes, and hamstrings, which directly answers the question.'}),
#  ({'id': 70, 'question': 'How should I land after completing a tuck jump?'},
#   'After completing a tuck jump, you should land softly and then repeat the movement.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing guidance on how to land after completing a tuck jump, specifically mentioning the importance of landing softly.'}),
#  ({'id': 161,
#    'question': 'What muscles are primarily activated during the Smith Machine Shoulder Press?'},
#   'The muscles primarily activated during the Smith Machine Shoulder Press are the Deltoids and Triceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the primary muscles (Deltoids and Triceps) activated during the Smith Machine Shoulder Press, directly addressing the question asked.'}),
#  ({'id': 5,
#    'question': 'Can you provide me with the correct stance for the Kettlebell Swing?'},
#   'The correct stance for the Kettlebell Swing is to stand with your feet slightly wider than shoulder-width apart. From this position, you swing the kettlebell between your legs and then up to shoulder height by driving your hips forward.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing the correct stance for the Kettlebell Swing, including important details about foot positioning and the swinging motion.'}),
#  ({'id': 135,
#    'question': 'What is the main action performed during the Seated Calf Raise?'},
#   'The main action performed during the Seated Calf Raise is to raise your heels as high as possible and then lower them back down.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the main action performed during the Seated Calf Raise, specifically focusing on raising and lowering the heels, which directly addresses the question.'}),
#  ({'id': 122,
#    'question': 'What body part does the Resistance Band Squat primarily focus on?'},
#   'The Resistance Band Squat primarily focuses on the Lower Body, specifically activating the Quadriceps, Glutes, and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that the Resistance Band Squat focuses on the Lower Body and specifies the muscles involved, which are the Quadriceps, Glutes, and Hamstrings. This information is pertinent to understanding which body parts are targeted by the exercise.'}),
#  ({'id': 37,
#    'question': 'Is the Renegade Rows exercise considered a strength training activity?'},
#   'Yes, the Renegade Rows exercise is considered a strength training activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly answers the question by stating that the Renegade Rows exercise is considered a strength training activity, which is exactly what was asked.'}),
#  ({'id': 151,
#    'question': 'Which equipment do I need to perform the Incline Chest Press?'},
#   'To perform the Incline Chest Press, you need Dumbbells.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions dumbbells, which is one piece of equipment commonly used for the Incline Chest Press. However, it fails to include other potential equipment options, such as an incline bench and a barbell, which are also relevant for performing the exercise. Therefore, while the answer is somewhat relevant, it lacks completeness.'}),
#  ({'id': 148,
#    'question': 'How do I perform the knee movement while doing Spider Push-Ups?'},
#   'To perform the knee movement while doing Spider Push-Ups, start in a high plank position. As you lower your body, bring one knee towards your elbow, then push back up and switch sides.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explaining how to incorporate the knee movement during Spider Push-Ups, detailing the proper positioning and movement steps clearly.'}),
#  ({'id': 189,
#    'question': 'What type of equipment is needed for performing a Pike Push-Up?'},
#   'The type of equipment needed for performing a Pike Push-Up is bodyweight.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer identifies that bodyweight is needed for performing a Pike Push-Up, which is accurate. However, it lacks information about other possible equipment or variations that could enhance or change the execution of the exercise, such as using a mat or wall for support.'}),
#  ({'id': 174,
#    'question': 'What equipment do I need for Weighted Russian Twists?'},
#   'To perform Weighted Russian Twists, you need a medicine ball.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions that a medicine ball is needed for Weighted Russian Twists, which is correct for one type of equipment. However, it does not provide a complete list of all possible equipment needed for this exercise, such as a dumbbell or kettlebell, making it only partly relevant.'}),
#  ({'id': 153,
#    'question': 'Which muscles are primarily targeted during Hanging Knee Raises?'},
#   'The muscles primarily targeted during Hanging Knee Raises are the Rectus Abdominis and the Hip Flexors.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the specific muscles, Rectus Abdominis and Hip Flexors, that are primarily targeted during Hanging Knee Raises, directly addressing the question asked.'}),
#  ({'id': 7,
#    'question': 'What is the primary muscle group targeted by the Lat Pulldown exercise?'},
#   'The primary muscle group targeted by the Lat Pulldown exercise is the Latissimus Dorsi.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the Latissimus Dorsi as the primary muscle group targeted by the Lat Pulldown exercise, directly addressing the question asked.'}),
#  ({'id': 126,
#    'question': 'What type of exercise is Dumbbell Flyes classified as?'},
#   'Dumbbell Flyes is classified as a Strength exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately classifies Dumbbell Flyes as a Strength exercise, directly addressing the question asked.'}),
#  ({'id': 69, 'question': 'What body part does the Landmine Press focus on?'},
#   'The Landmine Press focuses on the Upper Body.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that the Landmine Press focuses on the Upper Body, which is the expected and relevant information.'}),
#  ({'id': 190,
#    'question': 'What type of equipment do I need to perform the One-Arm Dumbbell Snatch?'},
#   'To perform the One-Arm Dumbbell Snatch, you need a dumbbell.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer correctly identifies that a dumbbell is needed to perform the One-Arm Dumbbell Snatch, but it lacks detail about other potential equipment or variations that could enhance the user’s understanding or performance of the exercise.'}),
#  ({'id': 80,
#    'question': 'Which body part does the Cable Chest Press primarily focus on?'},
#   'The Cable Chest Press primarily focuses on the Pectorals, which are the chest muscles.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the primary focus of the Cable Chest Press as the Pectorals, which directly addresses the question about which body part is emphasized during this exercise.'}),
#  ({'id': 68,
#    'question': 'What is the main focus of the Arnold Press exercise?'},
#   'The main focus of the Arnold Press exercise is to activate the deltoids and triceps in the upper body. It involves holding dumbbells at shoulder height, rotating your arms, and pressing the weights overhead.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the main focus of the Arnold Press exercise, mentioning the targeted muscle groups (deltoids and triceps) and the specific movement involved in the exercise, which directly addresses the question.'}),
#  ({'id': 30,
#    'question': 'What type of exercise is calf raises considered to be?'},
#   'Calf raises are considered to be a Strength exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by categorizing calf raises as a type of exercise, specifically identifying them as a strength exercise, which is an accurate classification.'}),
#  ({'id': 159,
#    'question': 'What movement pattern does the Smith Machine Row utilize?'},
#   'The Smith Machine Row utilizes a "Pull" movement pattern.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer accurately identifies the movement pattern associated with the Smith Machine Row as a 'Pull' movement pattern, directly addressing the question asked."}),
#  ({'id': 24, 'question': 'What type of activity is Step-Ups classified as?'},
#   'Step-Ups are classified as a type of activity called Strength.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies Step-Ups as a type of activity classified under Strength, which directly addresses the question asked.'}),
#  ({'id': 203,
#    'question': 'What is the primary muscle group targeted by the Machine Lat Pulldown exercise?'},
#   'The primary muscle group targeted by the Machine Lat Pulldown exercise is the Latissimus Dorsi.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by clearly stating that the primary muscle group targeted by the Machine Lat Pulldown exercise is the Latissimus Dorsi, which is accurate and specific.'}),
#  ({'id': 159,
#    'question': 'What type of exercise is the Smith Machine Row classified as?'},
#   'The Smith Machine Row is classified as a Strength exercise that involves pulling movements. It primarily targets the upper body, specifically activating the Latissimus Dorsi and Biceps muscle groups.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately classifies the Smith Machine Row as a strength exercise and provides additional relevant details, such as the nature of the movements and the specific muscle groups targeted. This directly answers the question asked.'}),
#  ({'id': 111,
#    'question': 'Is the Incline Dumbbell Curl considered a pull type exercise?'},
#   'Yes, the Incline Dumbbell Curl is considered a pull type exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by confirming that the Incline Dumbbell Curl is a pull type exercise, which is exactly what the question is asking.'}),
#  ({'id': 38,
#    'question': 'Can you describe the proper stance for my feet on the Leg Press machine?'},
#   'For the Leg Press machine, you should have your feet shoulder-width apart on the platform.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by specifying the proper stance for the feet on the Leg Press machine, which is to have them shoulder-width apart. This provides clear and relevant information for the user's inquiry."}),
#  ({'id': 91,
#    'question': 'What muscle groups are engaged when doing Walking Lunges?'},
#   'The muscle groups engaged when doing Walking Lunges are the Quadriceps, Glutes, and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the major muscle groups (Quadriceps, Glutes, and Hamstrings) that are engaged during Walking Lunges, directly addressing the question asked.'}),
#  ({'id': 1,
#    'question': 'Which muscle groups are activated when performing squats?'},
#   'When performing squats, the muscle groups activated are the Quadriceps, Glutes, and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly responds to the question by listing the specific muscle groups that are activated during squats, which are the Quadriceps, Glutes, and Hamstrings. This information is both accurate and pertinent to the question asked.'}),
#  ({'id': 119,
#    'question': 'What body part does the One-Arm Push-Up primarily target?'},
#   'The One-Arm Push-Up primarily targets the upper body. Specifically, it activates the muscle groups including the pectorals, triceps, and deltoids.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies that the One-Arm Push-Up primarily targets the upper body and specifies relevant muscle groups (pectorals, triceps, and deltoids), directly addressing the question.'}),
#  ({'id': 156,
#    'question': 'Can you explain the motion involved in the Machine Chest Press?'},
#   'The motion involved in the Machine Chest Press consists of sitting at the chest press machine with your feet flat on the floor. You then press the handles forward until your arms are fully extended. This action primarily engages the pectorals, triceps, and deltoids while performing a push movement.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by clearly explaining the motion involved in the Machine Chest Press, including the position of the body and the muscles engaged during the exercise.'}),
#  ({'id': 186,
#    'question': 'Can you explain the steps involved in executing the Deadlift High Pull properly?'},
#   'To execute the Deadlift High Pull properly, follow these steps:\n\n1. **Setup**: Start with a barbell placed on the ground in front of you.\n2. **Deadlift Position**: Stand with your feet hip-width apart. Bend at your hips and knees to grasp the barbell, ensuring your back is straight.\n3. **Lift**: Initiate the movement by performing a deadlift — lift the barbell by straightening your hips and knees, standing up tall.\n4. **Pull**: As you rise, begin to pull the barbell up towards your chest. Keep your elbows high and lead with them as you bring the bar towards your body.\n5. **Finish Position**: Raise the barbell until it reaches chest height, with your elbows still above the bar.\n6. **Lowering**: Reverse the movement by lowering the bar back down to the starting position and then perform the deadlift again if needed.\n\nMake sure to engage your glutes and hamstrings throughout the movement, as well as activate your shoulders during the pull phase.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides a clear and detailed step-by-step guide on how to execute the Deadlift High Pull properly, addressing the specific request in the question. It includes essential aspects like setup, lifting technique, and finishing position, which are crucial for understanding the movement.'}),
#  ({'id': 16,
#    'question': 'What is the name of the exercise focused on core strength?'},
#   'The name of the exercise focused on core strength is the "Superman Exercise."',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer correctly identifies the 'Superman Exercise' as an exercise focused on core strength, directly addressing the question asked."}),
#  ({'id': 66,
#    'question': 'Which leg do I need to lift when doing this exercise?'},
#   'When doing the exercise "Side Plank with Leg Lift," you need to lift your top leg towards the ceiling.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by specifying that the top leg should be lifted during the 'Side Plank with Leg Lift' exercise, making it clear and relevant to the inquiry about which leg to lift."}),
#  ({'id': 147,
#    'question': 'Can you describe the proper stance and movement for the Cable Kickback?'},
#   'For the Cable Kickback, you should stand facing a cable machine with a handle attached to the low pulley. From this position, extend your arm straight back, keeping your body stable. After fully extending your arm, return to the starting position to complete the movement.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the proper stance and movement for the Cable Kickback, mentioning the position relative to the cable machine and the action of extending and returning the arm. This directly addresses the question asked.'}),
#  ({'id': 29,
#    'question': "Can the Farmer's Walk be classified as strength or cardio?"},
#   "The Farmer's Walk can be classified as both strength and cardio. It involves holding heavy dumbbells while walking, which activates multiple muscle groups and can elevate the heart rate, fitting both classifications.",
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by stating that the Farmer's Walk can be classified as both strength and cardio. It provides a rationale for this classification, explaining how the exercise activates multiple muscle groups and elevates the heart rate, which supports its dual classification."}),
#  ({'id': 203,
#    'question': 'What specific grip should I use when performing the Machine Lat Pulldown?'},
#   'When performing the Machine Lat Pulldown, you should use a wide grip.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': "The generated answer directly addresses the question by specifying the grip type ('wide grip') to be used during the Machine Lat Pulldown, which is exactly what the question is asking for."}),
#  ({'id': 149,
#    'question': 'Can you provide the instructions for how to properly perform the Resistance Band Chest Press?'},
#   'To properly perform the Resistance Band Chest Press, follow these instructions:\n\n1. Attach a resistance band to a sturdy anchor behind you.\n2. Hold the handles of the band with your hands.\n3. Press the handles forward until your arms are fully extended.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides clear and specific instructions for performing the Resistance Band Chest Press, directly addressing the question. The steps outlined are appropriate and relevant to the exercise requested.'}),
#  ({'id': 127,
#    'question': 'Which muscle groups are primarily worked during the Reverse Fly?'},
#   'The muscle groups primarily worked during the Reverse Fly are the Rear Deltoids, Trapezius, and Rhomboids.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the muscle groups primarily worked during the Reverse Fly exercise, which directly addresses the question asked.'}),
#  ({'id': 155,
#    'question': 'Which muscle groups are primarily activated during the Glute Kickback?'},
#   'The muscle groups primarily activated during the Glute Kickback are the Glutes and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the primary muscle groups activated during the Glute Kickback, specifically mentioning the Glutes and Hamstrings, which directly addresses the question asked.'}),
#  ({'id': 18, 'question': 'What is the main action involved in Dumbbell Rows?'},
#   'The main action involved in Dumbbell Rows is to pull the dumbbells towards your torso while bending at the waist with your back straight.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the main action of Dumbbell Rows by detailing the movement of pulling the dumbbells towards the torso while maintaining proper posture, which directly addresses the question.'}),
#  ({'id': 74,
#    'question': 'How do I execute the movement for the Cable Bicep Curl correctly?'},
#   'To execute the Cable Bicep Curl correctly, follow these instructions: \n\n1. Stand facing a cable machine with the handle attached to a low pulley.\n2. Curl the handle towards your shoulders.\n3. Lower the handle back down to the starting position.\n\nMake sure to keep your elbows close to your body and maintain control throughout the movement for optimal results.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides clear and accurate instructions on how to execute the Cable Bicep Curl, directly addressing the question about correctly performing the exercise. It includes essential steps and tips for maintaining proper form, making it highly relevant to the question.'}),
#  ({'id': 9,
#    'question': 'What is the correct form for executing a jumping jack?'},
#   'To execute a jumping jack correctly, follow these instructions: \n\n1. Stand upright with your feet together and arms at your sides.\n2. Jump your feet out to the sides while simultaneously raising your arms overhead.\n3. Return to the starting position by jumping your feet back together and lowering your arms to your sides. \n\nRepeat this motion for the desired number of repetitions.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides a clear and accurate set of instructions for executing a jumping jack, directly addressing the question asked about the correct form for this exercise.'}),
#  ({'id': 206,
#    'question': 'What is the primary muscle group targeted by the Dumbbell Bench Press?'},
#   'The primary muscle group targeted by the Dumbbell Bench Press is the Pectorals.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the primary muscle group targeted by the Dumbbell Bench Press as the Pectorals, which directly answers the question.'}),
#  ({'id': 142,
#    'question': 'Which muscle groups are targeted when I do the Landmine Squat Press?'},
#   'The muscle groups targeted when doing the Landmine Squat Press are the Quadriceps, Glutes, and Shoulders.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by clearly listing the specific muscle groups (Quadriceps, Glutes, and Shoulders) that are targeted during the Landmine Squat Press, making it highly relevant to the inquiry.'}),
#  ({'id': 204,
#    'question': 'Which muscle groups are primarily worked during the One-Arm Cable Row?'},
#   'The muscle groups primarily worked during the One-Arm Cable Row are the Latissimus Dorsi and Biceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the primary muscle groups involved in the One-Arm Cable Row, specifically mentioning the Latissimus Dorsi and Biceps, which are indeed the key muscles targeted during this exercise.'}),
#  ({'id': 20, 'question': 'Which muscle groups does the Glute Bridge target?'},
#   'The Glute Bridge targets the Glutes and Hamstrings muscle groups.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying the specific muscle groups targeted by the Glute Bridge, which are the Glutes and Hamstrings. This aligns well with what the question is asking.'}),
#  ({'id': 36,
#    'question': 'What is the primary exercise for targeting the pectorals and triceps?'},
#   'The primary exercise for targeting the pectorals and triceps is the **Bench Press**.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying the Bench Press as the primary exercise for targeting both the pectorals and triceps, fulfilling the inquiry effectively.'}),
#  ({'id': 52,
#    'question': 'How do I maintain stability while tapping my shoulder?'},
#   'To maintain stability while tapping your shoulder, follow these instructions for the Plank Shoulder Taps exercise:\n\n1. Start in a high plank position with your body in a straight line from head to heels.\n2. Engage your core muscles to help stabilize your body.\n3. Slowly tap one hand to the opposite shoulder, ensuring your hips remain level and do not sway.\n4. Return the hand to the floor and switch sides, tapping the other hand to the opposite shoulder, while continuing to keep your body stable.\n\nFocus on controlled movements and keeping your core tight to enhance stability throughout the exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing step-by-step instructions on how to maintain stability while performing a shoulder tap exercise. It includes specific guidance on body positioning and core engagement, which are essential for achieving stability during the activity.'}),
#  ({'id': 97,
#    'question': 'Can you describe the proper stance for this exercise?'},
#   'For the Superman Exercise, the proper stance is to lie face down on the floor with your arms extended out in front of you. This position allows you to lift your arms, chest, and legs off the ground simultaneously, activating the lower back, glutes, and hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides a clear and accurate description of the proper stance for the Superman Exercise, directly addressing the question asked.'}),
#  ({'id': 100,
#    'question': 'What muscle groups are activated during the Cable Lateral Raise?'},
#   'The muscle groups activated during the Cable Lateral Raise are the Deltoids.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions the Deltoids, which is one of the primary muscle groups activated during the Cable Lateral Raise. However, it is not comprehensive, as it does not mention other muscle groups that may also be involved, such as the trapezius or supraspinatus. Therefore, while it provides some relevant information, it lacks depth and completeness.'}),
#  ({'id': 38,
#    'question': 'Which body part does the Leg Press primarily work on?'},
#   'The Leg Press primarily works on the Lower Body, specifically targeting the Quadriceps, Glutes, and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying that the Leg Press primarily works on the Lower Body and identifies the specific muscles involved, which are the Quadriceps, Glutes, and Hamstrings.'}),
#  ({'id': 190,
#    'question': 'Can you describe the starting position for the One-Arm Dumbbell Snatch?'},
#   'The starting position for the One-Arm Dumbbell Snatch involves placing a dumbbell between your feet.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly describes a key aspect of the starting position for the One-Arm Dumbbell Snatch by indicating that the dumbbell should be placed between the feet, which is an essential detail for performing the exercise.'}),
#  ({'id': 149,
#    'question': 'What equipment do I need for the Resistance Band Chest Press exercise?'},
#   'To perform the Resistance Band Chest Press exercise, you need a Resistance Band.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that a Resistance Band is needed for the Resistance Band Chest Press exercise, which is accurate and specific to the query.'}),
#  ({'id': 35,
#    'question': 'What muscles are primarily worked during a treadmill run?'},
#   'The muscles primarily worked during a treadmill run are the Quadriceps, Hamstrings, and Calves.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the primary muscles worked during a treadmill run, specifically mentioning the Quadriceps, Hamstrings, and Calves, which are all relevant to the question asked.'}),
#  ({'id': 99,
#    'question': 'What muscles are primarily worked during the Dumbbell Step-Up exercise?'},
#   'The muscles primarily worked during the Dumbbell Step-Up exercise are the Quadriceps, Glutes, and Hamstrings.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the primary muscles worked during the Dumbbell Step-Up exercise, which are the Quadriceps, Glutes, and Hamstrings, directly addressing the question.'}),
#  ({'id': 23, 'question': 'Is Cable Flyes considered a push or pull exercise?'},
#   'Cable Flyes are considered a push exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that Cable Flyes are considered a push exercise, which is the correct classification for this type of exercise.'}),
#  ({'id': 204,
#    'question': 'Which body part does the One-Arm Cable Row primarily target?'},
#   'The One-Arm Cable Row primarily targets the Upper Body, specifically activating the Latissimus Dorsi and Biceps muscle groups.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying the primary target muscle groups of the One-Arm Cable Row, which is specifically relevant to the question about which body part is targeted.'}),
#  ({'id': 40,
#    'question': 'What is the proper stance to take when performing a Single-Leg Deadlift?'},
#   'The proper stance to take when performing a Single-Leg Deadlift is to stand on one leg, holding a dumbbell in the opposite hand. You should bend at the hips to lower the weight while extending the free leg behind you.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question about the proper stance for a Single-Leg Deadlift by specifying the position of standing on one leg, the use of a dumbbell in the opposite hand, and the hip movement required. This information is precise and relevant to the question asked.'}),
#  ({'id': 6,
#    'question': 'What body part does the Shoulder Press primarily work on?'},
#   'The Shoulder Press primarily works on the upper body, specifically targeting the deltoids and triceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that the Shoulder Press primarily works on the upper body, specifically mentioning the deltoids and triceps, which are the main muscle groups targeted by this exercise.'}),
#  ({'id': 8,
#    'question': 'How should I position my body during the Hamstring Stretch?'},
#   'To position your body during the Hamstring Stretch, stand upright and place one heel on a bench or step. Lean forward slightly to feel a stretch in the hamstring of the elevated leg.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by providing specific instructions on how to position the body during the Hamstring Stretch, including standing upright, placing a heel on a bench, and leaning forward. This information is pertinent and useful for someone looking to perform the stretch correctly.'}),
#  ({'id': 62,
#    'question': 'Can you describe the proper stance to use while performing a Hack Squat on the machine?'},
#   'To perform a Hack Squat on the machine, you should stand on the hack squat machine platform. Begin by lowering your body by bending your knees. Once you reach the desired depth, push back up to the starting position. Make sure your feet are positioned correctly on the platform to ensure proper form and safety.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer provides some guidance on performing a Hack Squat, including instructions for lowering the body and ensuring foot placement. However, it lacks specific details about the proper stance, such as foot positioning and body alignment, which are critical for a comprehensive answer to the question.'}),
#  ({'id': 54,
#    'question': 'What type of activity is the Wall Sit classified as?'},
#   'The Wall Sit is classified as a Strength/Mobility activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately classifies the Wall Sit as a Strength/Mobility activity, which directly addresses the question asked.'}),
#  ({'id': 147,
#    'question': 'Which part of my body does the Cable Kickback primarily target?'},
#   'The Cable Kickback primarily targets the triceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the specific part of the body that the Cable Kickback targets, which is the triceps. This directly addresses the question asked.'}),
#  ({'id': 26, 'question': 'What part of the body does the Chest Press target?'},
#   'The Chest Press targets the upper body, specifically activating the pectorals, triceps, and deltoids.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying that the Chest Press targets the upper body and identifies the specific muscle groups involved, which are the pectorals, triceps, and deltoids.'}),
#  ({'id': 107,
#    'question': 'Can you describe the stance for the Bulgarian Deadlift?'},
#   'For the Bulgarian Deadlift, the stance involves standing on one leg while holding a dumbbell in each hand. You will then bend at the hips to lower the weights before lifting back up. This stance primarily focuses on engaging the hamstrings, glutes, and lower back.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the stance for the Bulgarian Deadlift, detailing the position of standing on one leg and the actions involved in the exercise. It also mentions the muscle groups engaged, which is pertinent information related to the question.'}),
#  ({'id': 27,
#    'question': 'What is the primary muscle group worked during box jumps?'},
#   'The primary muscle group worked during box jumps is the Quadriceps. Additionally, the Glutes and Calves are also activated during this exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the primary muscle group worked during box jumps as the Quadriceps, which directly addresses the question. It also provides additional information about the involvement of the Glutes and Calves, which enhances the answer without deviating from the main focus.'}),
#  ({'id': 17,
#    'question': 'What basic position should I start in when performing burpees?'},
#   'You should start in a standing position when performing burpees.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that one should start in a standing position when performing burpees, which is the correct basic position.'}),
#  ({'id': 145,
#    'question': 'What type of equipment is required to perform the Stability Ball Pike?'},
#   'The type of equipment required to perform the Stability Ball Pike is a Stability Ball.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying the specific piece of equipment required to perform the Stability Ball Pike, which is the Stability Ball. This is a complete and accurate response.'}),
#  ({'id': 73,
#    'question': 'What type of equipment do I need to perform the Sled Push?'},
#   'To perform the Sled Push, you need a sled.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer identifies that a sled is needed for the Sled Push, which is relevant. However, it lacks additional context or details about other potential equipment or setup that might be necessary, making it only partly relevant.'}),
#  ({'id': 85,
#    'question': 'What type of equipment do I need for the Hip Abduction?'},
#   'For the Hip Abduction exercise, you need a hip abduction machine.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying the equipment needed for the hip abduction exercise, which is the hip abduction machine. This clearly aligns with the inquiry about the type of equipment required.'}),
#  ({'id': 61,
#    'question': 'Is the Machine Chest Fly considered a push or pull exercise?'},
#   'The Machine Chest Fly is considered a push exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the Machine Chest Fly as a push exercise, which directly addresses the question about its classification as either a push or pull exercise.'}),
#  ({'id': 134,
#    'question': 'Can you explain the proper positioning for the Machine Row?'},
#   'To properly position yourself for the Machine Row, follow these instructions:\n\n1. Sit at the rowing machine and ensure your feet are braced securely in the designated foot area.\n2. Grasp the handles with a firm grip.\n3. Pull the handles towards your torso, engaging your core and maintaining good posture.\n4. Slowly return to the starting position to complete the movement.\n\nThis exercise primarily targets the Latissimus Dorsi and Biceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides clear and accurate instructions on the proper positioning for the Machine Row, addressing the question directly and including information about foot placement, grip, movement, and targeted muscles.'}),
#  ({'id': 15, 'question': 'Is Tricep Dips considered a strength exercise?'},
#   'Yes, Tricep Dips are considered a strength exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by confirming that Tricep Dips are indeed considered a strength exercise, providing a clear and accurate response.'}),
#  ({'id': 187,
#    'question': 'What type of equipment do I need for the Reverse Grip Lat Pulldown?'},
#   'For the Reverse Grip Lat Pulldown, you need a Cable Machine.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the necessary equipment, a Cable Machine, needed for performing the Reverse Grip Lat Pulldown, directly addressing the question.'}),
#  ({'id': 118,
#    'question': 'Is the Leg Curl considered a strength training exercise?'},
#   'Yes, the Leg Curl is considered a strength training exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by confirming that the Leg Curl is a strength training exercise, providing a clear and accurate response.'}),
#  ({'id': 198,
#    'question': 'Which muscle groups are primarily targeted by the Cable Tricep Overhead Extension?'},
#   'The Cable Tricep Overhead Extension primarily targets the triceps muscle group.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately identifies the primary muscle group targeted by the Cable Tricep Overhead Extension, directly addressing the question posed.'}),
#  ({'id': 99,
#    'question': 'What type of activity is the Dumbbell Step-Up classified as?'},
#   'The Dumbbell Step-Up is classified as a Strength activity.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately classifies the Dumbbell Step-Up as a Strength activity, directly addressing the question regarding the type of activity.'}),
#  ({'id': 173,
#    'question': 'How should I position my body before starting the Turkish Get-Up?'},
#   'Before starting the Turkish Get-Up, you should position your body by lying on your back while holding a kettlebell overhead.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explaining how to position the body (lying on the back) and specifies the use of a kettlebell overhead, which is essential for performing the Turkish Get-Up correctly.'}),
#  ({'id': 21,
#    'question': 'Is the Overhead Tricep Extension considered a strength exercise?'},
#   'Yes, the Overhead Tricep Extension is considered a strength exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly and accurately responds to the question by confirming that the Overhead Tricep Extension is indeed a strength exercise, providing clear and relevant information.'}),
#  ({'id': 171,
#    'question': 'What body part does the Banded Pull-Up focus on strengthening?'},
#   'The Banded Pull-Up focuses on strengthening the upper body, specifically activating the Latissimus Dorsi and Biceps muscles.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by identifying that the Banded Pull-Up focuses on strengthening the upper body, with a specific mention of the Latissimus Dorsi and Biceps muscles, which are the primary target areas.'}),
#  ({'id': 3, 'question': 'How should I grasp the barbell before lifting it?'},
#   'Before lifting the barbell, you should stand with your feet hip-width apart, bend at the hips and knees, and grasp the barbell. For specific exercises like the Deadlift and Sumo Deadlift, ensure to position your hands appropriately: for the Deadlift, grasp the bar in front of you, and for the Sumo Deadlift, grab the barbell with your hands inside your knees.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides specific instructions on how to grasp the barbell and also includes details about hand positioning for different exercises. This directly addresses the question and offers valuable information for effective barbell lifting.'}),
#  ({'id': 119,
#    'question': 'What should I do after lowering my body in the One-Arm Push-Up?'},
#   'After lowering your body in the One-Arm Push-Up until your chest nearly touches the floor, you should push back up to the starting position.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by explaining the necessary action to take after lowering the body in a One-Arm Push-Up, which is to push back up to the starting position. This provides a complete and relevant response to the query.'}),
#  ({'id': 110,
#    'question': 'Can you explain the correct technique for executing a kettlebell swing?'},
#   'To execute a kettlebell swing correctly, follow these steps:\n\n1. **Starting Position**: Stand with your feet slightly wider than shoulder-width apart.\n2. **Swing Motion**: Grip the kettlebell and swing it between your legs.\n3. **Hip Drive**: Drive your hips forward to propel the kettlebell upward.\n4. **Finish Position**: Swing the kettlebell to shoulder height.\n\nMake sure to engage your core and activate your glutes and hamstrings throughout the movement for optimal performance.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides a clear and detailed description of the correct technique for executing a kettlebell swing, covering key aspects such as starting position, swing motion, hip drive, finish position, and additional tips on engaging the core and muscles involved. This directly addresses the question asked.'}),
#  ({'id': 160,
#    'question': 'Can you describe the starting position for the Lat Pullover?'},
#   'The starting position for the Lat Pullover is to lie on a bench holding a dumbbell over your chest.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly describes the starting position for the Lat Pullover exercise, mentioning key details such as lying on a bench and holding a dumbbell over the chest, which directly addresses the question.'}),
#  ({'id': 197,
#    'question': 'What equipment do I need for the Cable Hammer Curl?'},
#   'For the Cable Hammer Curl, you need a Cable Machine.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by specifying the necessary equipment, which is the Cable Machine, for performing the Cable Hammer Curl.'}),
#  ({'id': 68, 'question': 'Which muscle groups does the Arnold Press work on?'},
#   'The Arnold Press works on the Deltoids and Triceps muscle groups.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer identifies the Deltoids and Triceps as the muscle groups worked on by the Arnold Press. While it correctly mentions some relevant muscle groups, it does not provide a comprehensive list or detailed explanation, such as mentioning the involvement of other muscle groups like the upper chest or rotation involved in the exercise.'}),
#  ({'id': 13,
#    'question': 'What is the starting position for Mountain Climbers?'},
#   'The starting position for Mountain Climbers is in a plank position.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the starting position for Mountain Climbers as being in a plank position, which directly answers the question.'}),
#  ({'id': 47,
#    'question': 'Which muscles are primarily worked during the Seated Shoulder Press?'},
#   'The muscles primarily worked during the Seated Shoulder Press are the Deltoids and Triceps.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the primary muscles worked during the Seated Shoulder Press, specifically mentioning the Deltoids and Triceps, which are both relevant to the question.'}),
#  ({'id': 51, 'question': 'What muscles are engaged during the Cable Row?'},
#   'During the Cable Row, the muscles engaged are the Latissimus Dorsi and Biceps.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer identifies two muscles that are engaged during the Cable Row, but it does not provide a comprehensive list of all muscles involved in this exercise. Other key muscles that are typically engaged include the Rhomboids, Trapezius, and Rear Deltoids. Thus, while the answer contains relevant information, it lacks depth.'}),
#  ({'id': 20,
#    'question': 'How do I properly execute the lift during the Glute Bridge?'},
#   'To properly execute the lift during the Glute Bridge, follow these instructions:\n\n1. Lie on your back with your knees bent and feet flat on the floor.\n2. Lift your hips until your body forms a straight line from your shoulders to your knees. \n\nMake sure to engage your glutes and hamstrings throughout the movement.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer provides clear and specific instructions on how to properly execute the lift during the Glute Bridge, directly addressing the question asked.'}),
#  ({'id': 60,
#    'question': 'Is the side lunge primarily a strength exercise for the lower body?'},
#   'Yes, the side lunge is primarily a strength exercise for the lower body. It activates the quadriceps, glutes, and adductors, which are key muscle groups in lower body strength training.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by confirming that the side lunge is primarily a strength exercise for the lower body and elaborates on the key muscle groups involved, which supports the assertion.'}),
#  ({'id': 186,
#    'question': 'Is the Deadlift High Pull considered a strength exercise or a cardio exercise?'},
#   'The Deadlift High Pull is considered a strength exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by stating that the Deadlift High Pull is considered a strength exercise, which is what the question is asking for.'}),
#  ({'id': 202,
#    'question': 'Is the Incline Dumbbell Row classified as a push or pull exercise?'},
#   'The Incline Dumbbell Row is classified as a pull exercise.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer directly addresses the question by correctly identifying the Incline Dumbbell Row as a pull exercise, providing a clear and accurate response.'}),
#  ({'id': 36,
#    'question': 'Which equipment is needed for performing the incline dumbbell press?'},
#   'The equipment needed for performing the incline dumbbell press is dumbbells.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer identifies dumbbells as necessary equipment for the incline dumbbell press. However, it does not mention the incline bench, which is also essential for performing this exercise. Therefore, while the answer provides some relevant information, it is incomplete.'}),
#  ({'id': 183,
#    'question': 'What type of activity classification does the Lateral Lunge fall under?'},
#   'The Lateral Lunge falls under the activity classification of Strength.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer correctly identifies the Lateral Lunge as falling under the activity classification of Strength, which directly addresses the question asked.'}),
#  ({'id': 39,
#    'question': 'What equipment do I need for the Cable Tricep Pushdown exercise?'},
#   'To perform the Cable Tricep Pushdown exercise, you need a Cable Machine.',
#   {'Relevance': 'PARTLY_RELEVANT',
#    'Explanation': 'The generated answer mentions the need for a Cable Machine, which is essential for the Cable Tricep Pushdown exercise. However, it lacks additional information about other possible equipment or accessories (like attachments, weights, etc.) that might enhance the understanding of what is needed for the exercise.'}),
#  ({'id': 140,
#    'question': 'Can you describe the starting position for the Lying Leg Curl?'},
#   'The starting position for the Lying Leg Curl involves lying face down on a leg curl machine.',
#   {'Relevance': 'RELEVANT',
#    'Explanation': 'The generated answer accurately describes the starting position for the Lying Leg Curl by stating that it involves lying face down on a leg curl machine, which directly addresses the question asked.'})]

# %%
#len(evaluations)
# Out:
# 88

# %%
df_eval = pd.DataFrame(evaluations, columns =['record','answer_llm','evaluation'])
#df_eval.shape
# Out:
# (100, 3)

# %%
#df_eval.head()
# Out:
#                                               record  \
# 0  {'id': 171, 'question': 'What is the primary m...
# 1  {'id': 115, 'question': 'Is any equipment need...
# 2  {'id': 53, 'question': 'Can you describe the p...
# 3  {'id': 198, 'question': 'What equipment do I n...
# 4  {'id': 19, 'question': 'Which part of the body...
#
#                                           answer_llm  \
# 0  The primary muscle group targeted by the Bande...
# 1  No equipment is needed for jumping squats, as ...
# 2  To perform a Dumbbell Lateral Raise with prope...
# 3  To perform the Cable Tricep Overhead Extension...
# 4  Goblet Squats primarily target the lower body,...
#
#                                           evaluation
# 0  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 1  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 2  {'Relevance': 'RELEVANT', 'Explanation': 'The ...
# 3  {'Relevance': 'PARTLY_RELEVANT', 'Explanation'...
# 4  {'Relevance': 'RELEVANT', 'Explanation': 'The ...

# %%
df_eval['id'] = df_eval.record.apply(lambda d: d['id'])
df_eval['question'] = df_eval.record.apply(lambda d: d['question'])
df_eval['Relevance'] = df_eval.evaluation.apply(lambda d: d['Relevance'])
df_eval['Explanation'] = df_eval.evaluation.apply(lambda d: d['Explanation'])

# %%
del df_eval['record']
del df_eval['evaluation']

# %%
df_eval.head()
# Out:
#                                           answer_llm   id  \
# 0  The primary muscle group targeted by the Bande...  171
# 1  No equipment is needed for jumping squats, as ...  115
# 2  To perform a Dumbbell Lateral Raise with prope...   53
# 3  To perform the Cable Tricep Overhead Extension...  198
# 4  Goblet Squats primarily target the lower body,...   19
#
#                                             question        Relevance  \
# 0  What is the primary muscle group targeted by t...         RELEVANT
# 1        Is any equipment needed for jumping squats?         RELEVANT
# 2  Can you describe the proper form for performin...         RELEVANT
# 3  What equipment do I need to perform the Cable ...  PARTLY_RELEVANT
# 4  Which part of the body does Goblet Squats prim...         RELEVANT
#
#                                          Explanation
# 0  The generated answer directly addresses the qu...
# 1  The generated answer directly addresses the qu...
# 2  The generated answer provides a clear and deta...
# 3  The generated answer mentions a Cable Machine,...
# 4  The generated answer accurately describes the ...

# %%
df_eval['Relevance'].value_counts()
# Out:
# Relevance
# RELEVANT           88
# PARTLY_RELEVANT    12
# Name: count, dtype: int64

# %%
df_eval['Relevance'].value_counts(normalize = True)
# Out:
# Relevance
# RELEVANT           0.88
# PARTLY_RELEVANT    0.12
# Name: proportion, dtype: float64
