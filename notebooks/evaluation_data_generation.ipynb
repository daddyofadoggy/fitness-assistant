# %%
import pandas as pd

# %%
import minsearch

# %% [markdown]
# ## Retrival Evaluation ##

# %%
df = pd.read_csv('../data/data.csv')
df.shape
# Out:
# (207, 8)

# %%
df.head()
# Out:
#    id exercise_name   type_of_activity type_of_equipment   body_part  type  \
# 0   0      Push-Ups           Strength        Bodyweight  Upper Body  Push
# 1   1        Squats           Strength        Bodyweight  Lower Body  Push
# 2   2         Plank  Strength/Mobility        Bodyweight        Core  Hold
# 3   3      Deadlift           Strength           Barbell  Lower Body  Pull
# 4   4   Bicep Curls           Strength         Dumbbells  Upper Body  Pull
#
#                   muscle_groups_activated  \
# 0            Pectorals, Triceps, Deltoids
# 1          Quadriceps, Glutes, Hamstrings
# 2  Rectus Abdominis, Transverse Abdominis
# 3          Glutes, Hamstrings, Lower Back
# 4                        Biceps, Forearms
#
#                                         instructions
# 0  Start in a high plank position with your hands...
# 1  Stand with feet shoulder-width apart. Lower yo...
# 2  Start in a forearm plank position with your el...
# 3  Stand with feet hip-width apart, barbell in fr...
# 4  Stand with a dumbbell in each hand, arms fully...

# %%
df.columns
# Out:
# Index(['id', 'exercise_name', 'type_of_activity', 'type_of_equipment',
#        'body_part', 'type', 'muscle_groups_activated', 'instructions'],
#       dtype='object')

# %%
documents = df.to_dict(orient='records')

# %%
documents
# Out:
# [{'id': 0,
#   'exercise_name': 'Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Start in a high plank position with your hands under your shoulders. Lower your body until your chest nearly touches the floor. Push back up to the starting position.'},
#  {'id': 1,
#   'exercise_name': 'Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand with feet shoulder-width apart. Lower your body as if sitting back into a chair, keeping your chest up. Return to standing.'},
#  {'id': 2,
#   'exercise_name': 'Plank',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Transverse Abdominis',
#   'instructions': 'Start in a forearm plank position with your elbows directly under your shoulders. Keep your body in a straight line from head to heels.'},
#  {'id': 3,
#   'exercise_name': 'Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet hip-width apart, barbell in front of you. Bend at the hips and knees to grasp the bar, then lift it by straightening your hips and knees.'},
#  {'id': 4,
#   'exercise_name': 'Bicep Curls',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with a dumbbell in each hand, arms fully extended. Curl the weights up to your shoulders while keeping your elbows close to your torso.'},
#  {'id': 5,
#   'exercise_name': 'Kettlebell Swing',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Stand with feet slightly wider than shoulder-width. Swing the kettlebell between your legs and then up to shoulder height by driving your hips forward.'},
#  {'id': 6,
#   'exercise_name': 'Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a dumbbell in each hand at shoulder height, then press them overhead until your arms are fully extended. Lower back to shoulder height.'},
#  {'id': 7,
#   'exercise_name': 'Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at the lat pulldown machine, grasp the bar with a wide grip, and pull it down to your chest. Slowly return to the starting position.'},
#  {'id': 8,
#   'exercise_name': 'Hamstring Stretch',
#   'type_of_activity': 'Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Stretch',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Stand upright and place one heel on a bench or step. Lean forward slightly to feel a stretch in the hamstring of the elevated leg.'},
#  {'id': 9,
#   'exercise_name': 'Jumping Jacks',
#   'type_of_activity': 'Cardio/Warm-up',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves, Deltoids, Glutes',
#   'instructions': 'Stand upright with feet together and arms at your sides. Jump your feet out while raising your arms overhead, then return to the starting position.'},
#  {'id': 10,
#   'exercise_name': 'Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie flat on a bench with a barbell. Lower the bar to your chest and push it back up to the starting position.'},
#  {'id': 11,
#   'exercise_name': 'Lunges',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step forward with one leg and lower your hips until both knees are bent at a 90-degree angle. Push back to the starting position.'},
#  {'id': 12,
#   'exercise_name': 'Pull-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grasp a pull-up bar with an overhand grip. Pull your body up until your chin is above the bar, then lower back down.'},
#  {'id': 13,
#   'exercise_name': 'Mountain Climbers',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors, Deltoids',
#   'instructions': 'Start in a plank position and alternate driving your knees towards your chest as quickly as possible.'},
#  {'id': 14,
#   'exercise_name': 'Leg Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with your legs extended. Lift your legs until they are perpendicular to the floor, then lower them back down.'},
#  {'id': 15,
#   'exercise_name': 'Tricep Dips',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps, Deltoids',
#   'instructions': 'Place your hands behind you on a bench or chair. Lower your body by bending your elbows, then push back up to the starting position.'},
#  {'id': 16,
#   'exercise_name': 'Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with your knees bent, lean back slightly, and twist your torso to each side, tapping the floor with your hands.'},
#  {'id': 17,
#   'exercise_name': 'Burpees',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Quadriceps, Core',
#   'instructions': 'Start in a standing position, drop into a squat, kick your feet back into a plank, return to the squat position, and jump up.'},
#  {'id': 18,
#   'exercise_name': 'Dumbbell Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'With a dumbbell in each hand, bend at the waist with your back straight. Pull the dumbbells towards your torso, then lower them back down.'},
#  {'id': 19,
#   'exercise_name': 'Goblet Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a kettlebell at chest level and squat down as if sitting in a chair. Return to standing.'},
#  {'id': 20,
#   'exercise_name': 'Glute Bridge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Lie on your back with knees bent and feet flat on the floor. Lift your hips until your body forms a straight line from shoulders to knees.'},
#  {'id': 21,
#   'exercise_name': 'Overhead Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Hold a dumbbell with both hands overhead, then lower it behind your head by bending your elbows. Extend your arms back to the starting position.'},
#  {'id': 22,
#   'exercise_name': 'Side Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Shoulders',
#   'instructions': 'Lie on one side with your legs straight. Lift your hips so your body forms a straight line, supporting yourself on one forearm.'},
#  {'id': 23,
#   'exercise_name': 'Cable Flyes',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. With a slight bend in your elbows, bring your hands together in front of your chest.'},
#  {'id': 24,
#   'exercise_name': 'Step-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes',
#   'instructions': 'Step onto a bench or box with one foot, then push through that foot to lift your body up. Step back down and repeat on the other side.'},
#  {'id': 25,
#   'exercise_name': 'Barbell Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet hip-width apart, bend forward at the hips, and row the barbell towards your torso. Lower it back down.'},
#  {'id': 26,
#   'exercise_name': 'Chest Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Press the weights straight up over your chest, then lower them back down.'},
#  {'id': 27,
#   'exercise_name': 'Box Jumps',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Stand in front of a sturdy box or bench. Jump onto the box, landing softly, then step back down.'},
#  {'id': 28,
#   'exercise_name': 'Hanging Leg Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Hang from a pull-up bar and raise your legs until they are parallel to the floor. Lower them back down slowly.'},
#  {'id': 29,
#   'exercise_name': "Farmer's Walk",
#   'type_of_activity': 'Strength/Cardio',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Full Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Forearms, Shoulders, Core',
#   'instructions': 'Hold a heavy dumbbell in each hand at your sides and walk forward while maintaining a straight posture.'},
#  {'id': 30,
#   'exercise_name': 'Calf Raises',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves',
#   'instructions': 'Stand with the balls of your feet on the edge of a step. Raise your heels as high as possible, then lower them back down.'},
#  {'id': 31,
#   'exercise_name': 'Battle Ropes',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Ropes',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Forearms, Core',
#   'instructions': 'Hold the ends of the ropes in each hand. Alternate waves with your arms to move the ropes up and down as quickly as possible.'},
#  {'id': 32,
#   'exercise_name': 'Medicine Ball Slams',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lift a medicine ball overhead and slam it down on the ground with as much force as possible. Catch it on the rebound and repeat.'},
#  {'id': 33,
#   'exercise_name': 'Dumbbell Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet hip-width apart, holding a dumbbell in each hand. Bend at the hips and knees to lower the weights, then lift back up.'},
#  {'id': 34,
#   'exercise_name': 'Push Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a barbell at shoulder height. Use your legs to help press the bar overhead, then lower it back to the starting position.'},
#  {'id': 35,
#   'exercise_name': 'Treadmill Run',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Treadmill',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Hamstrings, Calves',
#   'instructions': 'Run on a treadmill at a speed and incline that challenges your endurance.'},
#  {'id': 36,
#   'exercise_name': 'Incline Dumbbell Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench with a dumbbell in each hand. Press the weights up and together over your chest, then lower them back down.'},
#  {'id': 37,
#   'exercise_name': 'Renegade Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps, Core',
#   'instructions': 'Start in a plank position with a dumbbell in each hand. Row one dumbbell towards your torso while balancing on the other hand.'},
#  {'id': 38,
#   'exercise_name': 'Leg Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Sit on a leg press machine with your feet shoulder-width apart on the platform. Push the platform away by extending your legs.'},
#  {'id': 39,
#   'exercise_name': 'Cable Tricep Pushdown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing a cable machine with a high pulley. Push the handle downwards until your arms are fully extended.'},
#  {'id': 40,
#   'exercise_name': 'Single-Leg Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Stand on one leg, holding a dumbbell in the opposite hand. Bend at the hips to lower the weight while extending the free leg behind you.'},
#  {'id': 41,
#   'exercise_name': 'Inverted Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Lie under a bar or suspension trainer, pull your chest towards the bar while keeping your body straight, then lower back down.'},
#  {'id': 42,
#   'exercise_name': 'Pallof Press',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Transverse Abdominis',
#   'instructions': 'Stand sideways to a cable machine with the handle at chest height. Push the handle straight out in front of you, resisting the rotation.'},
#  {'id': 43,
#   'exercise_name': 'Kettlebell Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with feet shoulder-width apart, kettlebell between your feet. Bend at the hips and knees to lift the kettlebell off the ground.'},
#  {'id': 44,
#   'exercise_name': 'Hanging Knee Tucks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Hang from a pull-up bar and tuck your knees towards your chest, then slowly lower them back down.'},
#  {'id': 45,
#   'exercise_name': 'Resistance Band Pull Aparts',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Hold a resistance band in front of you with arms extended. Pull the band apart by bringing your hands out to your sides.'},
#  {'id': 46,
#   'exercise_name': 'Bulgarian Split Squats',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand lunge-style with one foot behind you on a bench. Lower your hips until your front thigh is parallel to the floor, then push back up.'},
#  {'id': 47,
#   'exercise_name': 'Seated Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a bench with a dumbbell in each hand at shoulder height. Press the weights overhead until your arms are fully extended.'},
#  {'id': 48,
#   'exercise_name': 'Incline Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Place your hands on an elevated surface like a bench. Lower your chest towards the surface, then push back up.'},
#  {'id': 49,
#   'exercise_name': 'Hip Thrusts',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Sit on the ground with your upper back against a bench, barbell across your hips. Lift your hips towards the ceiling by squeezing your glutes.'},
#  {'id': 50,
#   'exercise_name': 'Barbell Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with feet shoulder-width apart, holding a barbell with an underhand grip. Curl the bar towards your shoulders, then lower it back down.'},
#  {'id': 51,
#   'exercise_name': 'Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a cable row machine with feet braced. Pull the handle towards your torso, then slowly return to the starting position.'},
#  {'id': 52,
#   'exercise_name': 'Plank Shoulder Taps',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques, Deltoids',
#   'instructions': 'Start in a high plank position. Tap one hand to the opposite shoulder, then switch sides, while keeping your body stable.'},
#  {'id': 53,
#   'exercise_name': 'Dumbbell Lateral Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand with a dumbbell in each hand, arms at your sides. Raise your arms out to the sides until they are parallel to the floor.'},
#  {'id': 54,
#   'exercise_name': 'Wall Sit',
#   'type_of_activity': 'Strength/Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Quadriceps, Glutes',
#   'instructions': 'Lean against a wall with your feet shoulder-width apart. Slide down until your knees are at a 90-degree angle and hold the position.'},
#  {'id': 55,
#   'exercise_name': 'Spider Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques',
#   'instructions': 'Start in a forearm plank position. Bring one knee to the outside of your elbow, then return to the starting position and repeat on the other side.'},
#  {'id': 56,
#   'exercise_name': 'Sumo Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand with a wide stance, toes pointing out. Grasp the barbell with hands inside your knees, and lift it by extending your hips and knees.'},
#  {'id': 57,
#   'exercise_name': 'Single Arm Dumbbell Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Place one knee and hand on a bench for support, row the dumbbell towards your torso with the other hand.'},
#  {'id': 58,
#   'exercise_name': 'Kettlebell Clean and Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Swing the kettlebell up to shoulder height, then press it overhead. Lower it back down and repeat.'},
#  {'id': 59,
#   'exercise_name': 'Jump Rope',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Jump Rope',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves, Shoulders',
#   'instructions': 'Jump over the rope as it passes under your feet, keeping a steady rhythm.'},
#  {'id': 60,
#   'exercise_name': 'Side Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Step out to the side, bending one knee while keeping the other leg straight. Push back to the starting position.'},
#  {'id': 61,
#   'exercise_name': 'Machine Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Sit at a chest fly machine, grasp the handles, and bring them together in front of your chest, then return to the starting position.'},
#  {'id': 62,
#   'exercise_name': 'Hack Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on a hack squat machine platform, lower your body by bending your knees, then push back up to the starting position.'},
#  {'id': 63,
#   'exercise_name': 'Decline Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Place your feet on an elevated surface, hands on the floor. Lower your chest towards the floor, then push back up.'},
#  {'id': 64,
#   'exercise_name': 'Band Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a resistance band to a high anchor. Pull the band towards your face, leading with your elbows.'},
#  {'id': 65,
#   'exercise_name': 'Ab Wheel Rollout',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Ab Wheel',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Kneel on the floor with an ab wheel in front of you. Roll the wheel forward while keeping your core tight, then roll back.'},
#  {'id': 66,
#   'exercise_name': 'Side Leg Raises',
#   'type_of_activity': 'Mobility',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Glutes, Hip Flexors',
#   'instructions': 'Lie on your side with legs straight. Lift your top leg towards the ceiling, then lower it back down.'},
#  {'id': 67,
#   'exercise_name': 'Romanian Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Hold a barbell in front of your thighs. Bend at the hips to lower the bar down your legs, then return to standing.'},
#  {'id': 68,
#   'exercise_name': 'Arnold Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold dumbbells at shoulder height, palms facing you. Rotate your arms as you press the weights overhead, ending with palms facing forward.'},
#  {'id': 69,
#   'exercise_name': 'Landmine Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Deltoids, Triceps',
#   'instructions': 'Hold the end of a barbell anchored in a landmine attachment. Press the bar overhead with one arm.'},
#  {'id': 70,
#   'exercise_name': 'Tuck Jumps',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Jump straight up and tuck your knees towards your chest, then land softly and repeat.'},
#  {'id': 71,
#   'exercise_name': 'Windshield Wipers',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Rotate your legs side to side like windshield wipers.'},
#  {'id': 72,
#   'exercise_name': 'Dumbbell Shrugs',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Trapezius',
#   'instructions': 'Stand with a dumbbell in each hand at your sides. Shrug your shoulders towards your ears, then lower them back down.'},
#  {'id': 73,
#   'exercise_name': 'Sled Push',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sled',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Shoulders',
#   'instructions': 'Push a weighted sled across a flat surface, keeping your back straight and core tight.'},
#  {'id': 74,
#   'exercise_name': 'Cable Bicep Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand facing a cable machine with the handle attached to a low pulley. Curl the handle towards your shoulders, then lower it back down.'},
#  {'id': 75,
#   'exercise_name': 'Dumbbell Kickback',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Bend at the waist with a dumbbell in each hand. Extend your arms straight back, then return to the starting position.'},
#  {'id': 76,
#   'exercise_name': 'Flutter Kicks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with legs extended. Lift your feet off the ground and alternate kicking them up and down.'},
#  {'id': 77,
#   'exercise_name': 'High Knees',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Hip Flexors, Calves',
#   'instructions': 'Run in place while driving your knees towards your chest as high as possible.'},
#  {'id': 78,
#   'exercise_name': 'Sledgehammer Slams',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sledgehammer',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lift a sledgehammer overhead and slam it down onto a tire or other soft surface.'},
#  {'id': 79,
#   'exercise_name': 'Lateral Step-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step up onto a bench or box laterally with one foot, then bring the other foot up to meet it. Step back down and repeat.'},
#  {'id': 80,
#   'exercise_name': 'Cable Chest Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Stand in front of a cable machine with handles at chest height. Press the handles forward, then return to the starting position.'},
#  {'id': 81,
#   'exercise_name': 'TRX Rows',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'TRX',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grip the TRX handles and lean back, keeping your body straight. Pull your chest towards the handles, then lower back down.'},
#  {'id': 82,
#   'exercise_name': 'Medicine Ball Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with knees bent, holding a medicine ball. Twist your torso to each side, tapping the ball on the floor.'},
#  {'id': 83,
#   'exercise_name': 'Pendlay Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Bend over with a barbell on the floor. Row the barbell to your torso, then lower it back to the floor each rep.'},
#  {'id': 84,
#   'exercise_name': 'Side Plank with Leg Lift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Glutes, Shoulders',
#   'instructions': 'In a side plank position, lift your top leg towards the ceiling, then lower it back down.'},
#  {'id': 85,
#   'exercise_name': 'Hip Abduction',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hip Flexors',
#   'instructions': 'Sit on a hip abduction machine and press your legs apart against the resistance, then return to the starting position.'},
#  {'id': 86,
#   'exercise_name': 'Dumbbell Front Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand with a dumbbell in each hand, palms facing your thighs. Raise your arms in front of you until they are parallel to the floor.'},
#  {'id': 87,
#   'exercise_name': 'Chin-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Grip a pull-up bar with an underhand grip. Pull your body up until your chin is above the bar, then lower back down.'},
#  {'id': 88,
#   'exercise_name': 'Box Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand in front of a box with a barbell on your shoulders. Squat down until you sit on the box, then stand back up.'},
#  {'id': 89,
#   'exercise_name': 'Battle Rope Waves',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Ropes',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Forearms, Core',
#   'instructions': 'Hold the ends of the ropes and create waves by alternating your arms up and down rapidly.'},
#  {'id': 90,
#   'exercise_name': 'Zercher Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a barbell in the crook of your elbows. Squat down until your thighs are parallel to the floor, then push back up.'},
#  {'id': 91,
#   'exercise_name': 'Walking Lunges',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step forward into a lunge, then bring your back foot forward to step into the next lunge.'},
#  {'id': 92,
#   'exercise_name': 'Kettlebell Snatch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Swing a kettlebell between your legs, then pull it overhead in one motion.'},
#  {'id': 93,
#   'exercise_name': 'Single-Leg Glute Bridge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Lie on your back with one foot on the ground and the other leg extended. Lift your hips towards the ceiling.'},
#  {'id': 94,
#   'exercise_name': 'TRX Push-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'TRX',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Perform push-ups with your hands in the TRX handles, keeping your body straight.'},
#  {'id': 95,
#   'exercise_name': 'Machine Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Sit on a leg curl machine and curl the pad down towards your glutes, then return to the starting position.'},
#  {'id': 96,
#   'exercise_name': 'Incline Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench with a barbell. Press the bar up and together over your chest, then lower it back down.'},
#  {'id': 97,
#   'exercise_name': 'Resistance Band Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Lower Back',
#   'instructions': 'Stand on a resistance band with feet shoulder-width apart. Bend at the hips and knees to lift the band off the ground.'},
#  {'id': 98,
#   'exercise_name': 'Decline Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a decline bench with a barbell. Lower the bar to your chest, then press it back up.'},
#  {'id': 99,
#   'exercise_name': 'Dumbbell Step-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step onto a bench with one foot while holding dumbbells, then bring the other foot up to meet it.'},
#  {'id': 100,
#   'exercise_name': 'Cable Lateral Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand next to a cable machine with the handle at the low pulley. Raise your arm out to the side until it is parallel to the floor.'},
#  {'id': 101,
#   'exercise_name': 'Reverse Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Step backward into a lunge, lowering your hips until both knees are at a 90-degree angle.'},
#  {'id': 102,
#   'exercise_name': 'Toe Touches',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Reach your hands towards your toes.'},
#  {'id': 103,
#   'exercise_name': 'Machine Leg Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps',
#   'instructions': 'Sit on a leg extension machine and extend your legs until they are straight, then return to the starting position.'},
#  {'id': 104,
#   'exercise_name': 'Dumbbell Pullover',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Pectorals, Triceps',
#   'instructions': 'Lie on a bench holding a dumbbell over your chest. Lower the weight behind your head, then pull it back up.'},
#  {'id': 105,
#   'exercise_name': 'Barbell Shrug',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Trapezius',
#   'instructions': 'Stand with feet shoulder-width apart, holding a barbell. Shrug your shoulders towards your ears, then lower them back down.'},
#  {'id': 106,
#   'exercise_name': 'T-Bar Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet shoulder-width apart, holding a T-bar. Row the weight towards your torso, then lower it back down.'},
#  {'id': 107,
#   'exercise_name': 'Bulgarian Deadlift',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings, Glutes, Lower Back',
#   'instructions': 'Stand on one leg holding a dumbbell in each hand. Bend at the hips to lower the weights, then lift back up.'},
#  {'id': 108,
#   'exercise_name': 'Pistol Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg with the other leg extended in front of you. Lower your hips until your thigh is parallel to the floor, then push back up.'},
#  {'id': 109,
#   'exercise_name': 'Seated Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Sit on a leg curl machine and curl the pad down towards your glutes, then return to the starting position.'},
#  {'id': 110,
#   'exercise_name': 'Russian Kettlebell Swing',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Swing the kettlebell between your legs and up to shoulder height, driving the movement with your hips.'},
#  {'id': 111,
#   'exercise_name': 'Incline Dumbbell Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Sit on an incline bench with a dumbbell in each hand. Curl the weights up towards your shoulders, then lower them back down.'},
#  {'id': 112,
#   'exercise_name': 'Decline Sit-Ups',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on a decline bench and sit up, bringing your chest towards your knees.'},
#  {'id': 113,
#   'exercise_name': 'Side Plank Dips',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Shoulders',
#   'instructions': 'Start in a side plank position. Lower your hips towards the floor, then lift them back up.'},
#  {'id': 114,
#   'exercise_name': 'Single Arm Kettlebell Swing',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Core',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Swing the kettlebell between your legs and up to shoulder height with one hand, driving the movement with your hips.'},
#  {'id': 115,
#   'exercise_name': 'Jumping Squats',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Calves',
#   'instructions': 'Lower into a squat, then explode upwards into a jump. Land softly and repeat.'},
#  {'id': 116,
#   'exercise_name': 'Cable Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. Bring the handles together in front of your chest, then return to the starting position.'},
#  {'id': 117,
#   'exercise_name': 'Dumbbell Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Hold a dumbbell with both hands overhead, then lower it behind your head by bending your elbows. Extend your arms back to the starting position.'},
#  {'id': 118,
#   'exercise_name': 'Leg Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Lie face down on a leg curl machine and curl the pad towards your glutes, then return to the starting position.'},
#  {'id': 119,
#   'exercise_name': 'One-Arm Push-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Start in a push-up position with one hand behind your back. Lower your body until your chest nearly touches the floor, then push back up.'},
#  {'id': 120,
#   'exercise_name': 'Machine Shoulder Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a shoulder press machine, grasp the handles, and press them overhead until your arms are fully extended.'},
#  {'id': 121,
#   'exercise_name': 'Sumo Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand with feet wider than shoulder-width apart, toes pointing out. Lower your hips until your thighs are parallel to the floor, then push back up.'},
#  {'id': 122,
#   'exercise_name': 'Resistance Band Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on a resistance band with feet shoulder-width apart. Squat down while holding the band at shoulder height.'},
#  {'id': 123,
#   'exercise_name': 'One-Legged Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg with the other leg extended in front of you. Lower your hips until your thigh is parallel to the floor, then push back up.'},
#  {'id': 124,
#   'exercise_name': 'Landmine Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Place one end of a barbell in a landmine attachment. Row the other end towards your torso with both hands, then lower it back down.'},
#  {'id': 125,
#   'exercise_name': 'Superman Exercise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Lower Back, Glutes, Hamstrings',
#   'instructions': 'Lie face down on the floor with arms extended. Lift your arms, chest, and legs off the ground simultaneously, then lower them back down.'},
#  {'id': 126,
#   'exercise_name': 'Dumbbell Flyes',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Lower the weights out to the sides of your chest, then bring them back together over your chest.'},
#  {'id': 127,
#   'exercise_name': 'Reverse Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Stand with feet hip-width apart, bend forward at the hips, and raise the dumbbells out to the sides until they are parallel to the floor.'},
#  {'id': 128,
#   'exercise_name': 'Cable Kickbacks',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Hamstrings',
#   'instructions': 'Attach an ankle strap to a low cable pulley. Kick your leg back while keeping your knee slightly bent, then return to the starting position.'},
#  {'id': 129,
#   'exercise_name': 'Kettlebell Push Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Hold a kettlebell at shoulder height. Use your legs to help press the kettlebell overhead, then lower it back down.'},
#  {'id': 130,
#   'exercise_name': 'Dead Bug',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with arms extended towards the ceiling. Lower opposite arm and leg towards the floor while keeping your back flat.'},
#  {'id': 131,
#   'exercise_name': 'Smith Machine Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
# ...
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Hamstrings',
#   'instructions': 'Lie face down on a leg curl machine and curl the pad towards your glutes, then return to the starting position.'},
#  {'id': 165,
#   'exercise_name': 'Seated Dumbbell Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Sit on a bench with a dumbbell in each hand at shoulder height. Press the weights overhead until your arms are fully extended.'},
#  {'id': 166,
#   'exercise_name': 'Weighted Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Obliques, Shoulders',
#   'instructions': 'Start in a forearm plank position with a weight plate on your back. Hold the position while keeping your body straight.'},
#  {'id': 167,
#   'exercise_name': 'Step Mill',
#   'type_of_activity': 'Cardio',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings, Calves',
#   'instructions': 'Step continuously on a revolving staircase, keeping a steady pace.'},
#  {'id': 168,
#   'exercise_name': 'Standing Resistance Band Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Attach a resistance band to a sturdy anchor. Pull the handles towards your torso, keeping your elbows close to your body.'},
#  {'id': 169,
#   'exercise_name': 'Dumbbell Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Hold a dumbbell in each hand and step forward into a lunge. Push back to the starting position and repeat on the other leg.'},
#  {'id': 170,
#   'exercise_name': 'Reverse Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand with feet shoulder-width apart, holding a dumbbell in each hand with an overhand grip. Curl the weights up towards your shoulders.'},
#  {'id': 171,
#   'exercise_name': 'Banded Pull-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Resistance Band',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Loop a resistance band around a pull-up bar and place your knees in the band. Pull your body up until your chin is above the bar.'},
#  {'id': 172,
#   'exercise_name': 'Cable Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a rope handle to a high cable pulley. Pull the handle towards your face, leading with your elbows.'},
#  {'id': 173,
#   'exercise_name': 'Turkish Get-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Kettlebell',
#   'body_part': 'Full Body',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Core, Shoulders, Glutes',
#   'instructions': 'Lie on your back holding a kettlebell overhead. Stand up while keeping the kettlebell above your head, then return to lying.'},
#  {'id': 174,
#   'exercise_name': 'Weighted Russian Twists',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Medicine Ball',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on the floor with knees bent, holding a medicine ball. Twist your torso to each side, tapping the ball on the floor.'},
#  {'id': 175,
#   'exercise_name': 'Cable Front Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids',
#   'instructions': 'Stand facing a cable machine with the handle at the low pulley. Raise the handle in front of you until your arm is parallel to the floor.'},
#  {'id': 176,
#   'exercise_name': 'Reverse Crunch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Rectus Abdominis, Hip Flexors',
#   'instructions': 'Lie on your back with legs extended towards the ceiling. Lift your hips off the ground, bringing your knees towards your chest.'},
#  {'id': 177,
#   'exercise_name': 'Cable Tricep Kickback',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing a cable machine with a handle attached to the low pulley. Extend your arm straight back, then return to the starting position.'},
#  {'id': 178,
#   'exercise_name': 'Copenhagen Plank',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Hold',
#   'muscle_groups_activated': 'Obliques, Adductors',
#   'instructions': 'Lie on your side with your top leg on a bench and your bottom leg extended. Lift your hips to form a straight line from head to heels.'},
#  {'id': 179,
#   'exercise_name': 'Smith Machine Incline Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on an incline bench under a Smith machine bar. Press the bar up and together over your chest, then lower it back down.'},
#  {'id': 180,
#   'exercise_name': 'Cable Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine, grasp the bar with a wide grip, and pull it down to your chest. Slowly return to the starting position.'},
#  {'id': 181,
#   'exercise_name': 'Cable Side Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Attach a handle to a low pulley and stand to the side of the cable machine. Step out into a side lunge, then return to the starting position.'},
#  {'id': 182,
#   'exercise_name': 'Dumbbell Bent-Over Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand with feet shoulder-width apart, bend forward at the hips, and row the dumbbells towards your torso.'},
#  {'id': 183,
#   'exercise_name': 'Lateral Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Step out to the side, bending one knee while keeping the other leg straight. Push back to the starting position.'},
#  {'id': 184,
#   'exercise_name': 'Seated Machine Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a rowing machine with feet braced. Pull the handles towards your torso, then slowly return to the starting position.'},
#  {'id': 185,
#   'exercise_name': 'Decline Russian Twist',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Core',
#   'type': 'Twist',
#   'muscle_groups_activated': 'Obliques, Rectus Abdominis',
#   'instructions': 'Sit on a decline bench with your knees bent. Twist your torso to each side, tapping your hands on the floor.'},
#  {'id': 186,
#   'exercise_name': 'Deadlift High Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Barbell',
#   'body_part': 'Full Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Hamstrings, Shoulders',
#   'instructions': 'Start with a barbell on the ground, perform a deadlift, and as you stand up, pull the barbell up towards your chest.'},
#  {'id': 187,
#   'exercise_name': 'Reverse Grip Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine with a reverse grip. Pull the bar down to your chest, then slowly return to the starting position.'},
#  {'id': 188,
#   'exercise_name': 'Cable Lateral Lunge',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Adductors',
#   'instructions': 'Attach a handle to a low pulley and stand to the side of the cable machine. Step out into a side lunge, then return to the starting position.'},
#  {'id': 189,
#   'exercise_name': 'Pike Push-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Deltoids, Triceps',
#   'instructions': 'Start in a downward dog position with your hips raised. Lower your head towards the floor, then push back up.'},
#  {'id': 190,
#   'exercise_name': 'One-Arm Dumbbell Snatch',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbell',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Shoulders, Triceps',
#   'instructions': 'Start with a dumbbell between your feet. Explosively pull the dumbbell up and overhead in one motion.'},
#  {'id': 191,
#   'exercise_name': 'Cable Front Squat',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Attach a rope handle to a low pulley and stand facing the cable machine. Squat down while holding the rope at chest height.'},
#  {'id': 192,
#   'exercise_name': 'Tire Flip',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Tire',
#   'body_part': 'Full Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Glutes, Quadriceps, Hamstrings, Shoulders',
#   'instructions': 'Squat down and grab the edge of a tire. Lift the tire and flip it forward.'},
#  {'id': 193,
#   'exercise_name': 'Smith Machine Calf Raise',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Smith Machine',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Calves',
#   'instructions': 'Stand under the bar of a Smith machine with the balls of your feet on a step. Raise your heels as high as possible, then lower them back down.'},
#  {'id': 194,
#   'exercise_name': 'Pistol Squat to Box',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight',
#   'body_part': 'Lower Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Quadriceps, Glutes, Hamstrings',
#   'instructions': 'Stand on one leg in front of a box. Lower your hips until you sit on the box, then stand back up.'},
#  {'id': 195,
#   'exercise_name': 'Standing Chest Fly',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Deltoids',
#   'instructions': 'Stand in the middle of a cable machine with handles in each hand. Bring the handles together in front of your chest, then return to the starting position.'},
#  {'id': 196,
#   'exercise_name': 'Sled Drag',
#   'type_of_activity': 'Cardio/Strength',
#   'type_of_equipment': 'Sled',
#   'body_part': 'Full Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Glutes, Quadriceps, Hamstrings, Shoulders',
#   'instructions': 'Attach a harness to a sled and drag it across a flat surface, walking or running backwards.'},
#  {'id': 197,
#   'exercise_name': 'Cable Hammer Curl',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Biceps, Forearms',
#   'instructions': 'Stand facing a cable machine with the handle attached to the low pulley. Curl the handle towards your shoulders with a neutral grip.'},
#  {'id': 198,
#   'exercise_name': 'Cable Tricep Overhead Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Stand facing away from a cable machine with the handle attached to the low pulley. Extend the handle overhead until your arms are fully extended.'},
#  {'id': 199,
#   'exercise_name': 'Seated Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a cable row machine with feet braced. Pull the handle towards your torso, then slowly return to the starting position.'},
#  {'id': 200,
#   'exercise_name': 'Lying Dumbbell Tricep Extension',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Triceps',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Lower the weights towards your head by bending your elbows, then extend your arms back to the starting position.'},
#  {'id': 201,
#   'exercise_name': 'Weighted Pull-Up',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Bodyweight/Dumbbell',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Hang a weight from your waist and perform a pull-up, bringing your chin above the bar.'},
#  {'id': 202,
#   'exercise_name': 'Incline Dumbbell Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Lie face down on an incline bench with a dumbbell in each hand. Row the weights towards your torso, then lower them back down.'},
#  {'id': 203,
#   'exercise_name': 'Machine Lat Pulldown',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Sit at a lat pulldown machine with a wide grip. Pull the bar down to your chest, then slowly return to the starting position.'},
#  {'id': 204,
#   'exercise_name': 'One-Arm Cable Row',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Latissimus Dorsi, Biceps',
#   'instructions': 'Stand facing a cable machine with the handle attached to the low pulley. Row the handle towards your torso with one hand.'},
#  {'id': 205,
#   'exercise_name': 'Face Pull',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Cable Machine',
#   'body_part': 'Upper Body',
#   'type': 'Pull',
#   'muscle_groups_activated': 'Rear Deltoids, Trapezius, Rhomboids',
#   'instructions': 'Attach a rope handle to a high cable pulley. Pull the handle towards your face, leading with your elbows.'},
#  {'id': 206,
#   'exercise_name': 'Dumbbell Bench Press',
#   'type_of_activity': 'Strength',
#   'type_of_equipment': 'Dumbbells',
#   'body_part': 'Upper Body',
#   'type': 'Push',
#   'muscle_groups_activated': 'Pectorals, Triceps, Deltoids',
#   'instructions': 'Lie on a bench with a dumbbell in each hand. Press the weights up and together over your chest, then lower them back down.'}]

# %%
prompt_template = """
You emulate a user of our fitness assistant application.
Formulate 5 questions this user might ask based on a provided exercise.
Make the questions specific to this exercise.
The record should contain the answer to the questions, and the questions should
be complete and not too short. Use as fewer words as possible from the record. 

The record:

exercise_name: {exercise_name}
type_of_activity: {type_of_activity}
type_of_equipment: {type_of_equipment}
body_part: {body_part}
type: {type}
muscle_groups_activated: {muscle_groups_activated}
instructions: {instructions}

Provide the output in parsable JSON without using code blocks:

{{"questions": ["question1", "question2", ..., "question5"]}}
""".strip()

# %%
prompt = prompt_template.format(**documents[0])

# %%
print(prompt)
# Out:
# You emulate a user of our fitness assistant application.
# Formulate 5 questions this user might ask based on a provided exercise.
# Make the questions specific to this exercise.
# The record should contain the answer to the questions, and the questions should
# be complete and not too short. Use as fewer words as possible from the record.
#
# The record:
#
# exercise_name: Push-Ups
# type_of_activity: Strength
# type_of_equipment: Bodyweight
# body_part: Upper Body
# type: Push
# muscle_groups_activated: Pectorals, Triceps, Deltoids
# instructions: Start in a high plank position with your hands under your shoulders. Lower your body until your chest nearly touches the floor. Push back up to the starting position.
#
# Provide the output in parsable JSON without using code blocks:
#
# {"questions": ["question1", "question2", ..., "question5"]}

# %%
import os

# %%
#os.environ['OPENAI_API_KEY'] = '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'

# %%
from openai import OpenAI
client = OpenAI()

# %%
def llm(prompt):
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
res = llm(prompt)

# %%
print(res)
# Out:
# {"questions": ["What is the correct starting position for doing push-ups?", "Which muscle groups are primarily targeted by push-ups?", "How should I lower my body during a push-up?", "Do I need any equipment to perform push-ups?", "How do I return to the starting position after lowering my body?"]}

# %%
import json
json.loads(res)
# Out:
# {'questions': ['What is the correct starting position for doing push-ups?',
#   'Which muscle groups are primarily targeted by push-ups?',
#   'How should I lower my body during a push-up?',
#   'Do I need any equipment to perform push-ups?',
#   'How do I return to the starting position after lowering my body?']}

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)
    results = llm(prompt)
    return results

# %%
from tqdm.auto import tqdm

# %%
results = {}
for doc in tqdm(documents):
    if doc['id'] in results:
        continue
    questions_raw = generate_questions(doc)
    questions = json.loads(questions_raw)
    results[doc['id']] = questions
# Out:
#   0%|          | 0/207 [00:00<?, ?it/s]

# %%
results
# Out:
# {0: {'questions': ['What is the starting position for push-ups?',
#    'Which muscle groups are targeted during push-ups?',
#    'Do I need any equipment to perform push-ups?',
#    'How do I properly lower my body during a push-up?',
#    'What type of exercise are push-ups classified as?']},
#  1: {'questions': ['What body position should I maintain during squats?',
#    'Which muscle groups are activated when performing squats?',
#    'Do I need any equipment to perform squats?',
#    'How should my feet be positioned while doing squats?',
#    'What is the proper motion for lowering my body during squats?']},
#  2: {'questions': ['What is the correct starting position for the Plank exercise?',
#    'Which muscle groups are primarily activated during the Plank?',
#    'How should my body be aligned while holding a Plank?',
#    'What type of exercise is Plank classified as?',
#    'Do I need any equipment to perform the Plank?']},
#  3: {'questions': ['What is the proper stance for performing a deadlift?',
#    'Which part of the body does the deadlift primarily work?',
#    'How should I grasp the barbell before lifting it?',
#    'What muscles will be activated during a deadlift?',
#    'Can you describe the movement involved in lifting the barbell?']},
#  4: {'questions': ['What muscles are targeted by bicep curls?',
#    'What is the correct starting position for bicep curls?',
#    'Do I need any equipment to perform bicep curls?',
#    'How should my elbows be positioned during the exercise?',
#    'What type of exercise are bicep curls classified as?']},
#  5: {'questions': ['What equipment do I need for the Kettlebell Swing?',
#    'Which muscle groups are primarily activated during the Kettlebell Swing?',
#    'Can you provide me with the correct stance for the Kettlebell Swing?',
#    'What type of activity does the Kettlebell Swing fall under?',
#    'What is the main movement technique for swinging the kettlebell up?']},
#  6: {'questions': ['What equipment do I need to perform the Shoulder Press exercise?',
#    'Which muscle groups are targeted when doing the Shoulder Press?',
#    'Can you explain the proper form for the Shoulder Press?',
#    'Is the Shoulder Press considered a push or pull exercise?',
#    'What body part does the Shoulder Press primarily work on?']},
#  7: {'questions': ['What is the primary muscle group targeted by the Lat Pulldown exercise?',
#    'How should I grip the bar when performing the Lat Pulldown?',
#    'What is the correct starting position for the Lat Pulldown?',
#    'Can the Lat Pulldown help strengthen my biceps?',
#    'What type of exercise equipment is needed for the Lat Pulldown?']},
#  8: {'questions': ['What equipment do I need for the Hamstring Stretch?',
#    'How should I position my body during the Hamstring Stretch?',
#    'Which muscle group does the Hamstring Stretch target?',
#    'What part of the body is primarily involved in the Hamstring Stretch?',
#    'Is the Hamstring Stretch considered a mobility exercise?']},
#  9: {'questions': ['What are jumping jacks primarily used for in fitness routines?',
#    'Which body parts does performing jumping jacks activate?',
#    'Do I need any equipment to perform jumping jacks?',
#    'Can jumping jacks serve as both a cardio and warm-up exercise?',
#    'What is the correct form for executing a jumping jack?']},
#  10: {'questions': ['What is the correct starting position for the bench press exercise?',
#    'Which muscle groups are primarily targeted during the bench press?',
#    'Can you explain how to perform the bench press correctly?',
#    'What type of equipment is needed to do a bench press?',
#    'Is the bench press an upper body exercise or a lower body exercise?']},
#  11: {'questions': ['What type of exercise are lunges classified as?',
#    'Which body parts are primarily targeted during lunges?',
#    'What equipment do I need to perform lunges?',
#    'Can you explain the proper form for a lunge?',
#    'What muscle groups are activated when doing lunges?']},
#  12: {'questions': ['What grip should I use when performing pull-ups?',
#    'Which muscles are worked during pull-ups?',
#    'Can I do pull-ups without any equipment?',
#    'What is the proper technique for doing pull-ups?',
#    'What part of the body do pull-ups primarily target?']},
#  13: {'questions': ['What is the starting position for Mountain Climbers?',
#    'Which muscle groups are activated during Mountain Climbers?',
#    'Is any equipment needed to perform Mountain Climbers?',
#    'How should I drive my knees when doing this exercise?',
#    'Is Mountain Climbers primarily a cardio or strength exercise?']},
#  14: {'questions': ['What is the primary body part targeted by the Leg Raises exercise?',
#    'What muscle groups are activated when performing Leg Raises?',
#    'How should I position my body when doing Leg Raises?',
#    'What type of activity are Leg Raises categorized under?',
#    'Is any equipment needed for Leg Raises, or can it be done with just bodyweight?']},
#  15: {'questions': ['What equipment do I need to perform Tricep Dips?',
#    'Which muscle groups are activated during Tricep Dips?',
#    'Can you explain the proper technique for executing Tricep Dips?',
#    'Is Tricep Dips considered a strength exercise?',
#    'What part of the body is primarily targeted by Tricep Dips?']},
#  16: {'questions': ['What is the name of the exercise focused on core strength?',
#    'What muscle groups does the Russian Twists exercise target?',
#    'What position should I be in while performing Russian Twists?',
#    'Do I need any equipment to do Russian Twists?',
#    'How do I execute the twisting motion in Russian Twists?']},
#  17: {'questions': ['What basic position should I start in when performing burpees?',
#    'Which muscle groups are primarily targeted during burpees?',
#    'Can you explain the step-by-step process to correctly perform a burpee?',
#    'Is any equipment necessary for doing burpees?',
#    'What type of exercise are burpees classified as?']},
#  18: {'questions': ['What muscles are primarily worked during Dumbbell Rows?',
#    'Can you describe the proper form for performing Dumbbell Rows?',
#    'What type of equipment do I need for Dumbbell Rows?',
#    'Is Dumbbell Rows an upper body or lower body exercise?',
#    'What is the main action involved in Dumbbell Rows?']},
#  19: {'questions': ['What is the primary equipment needed for Goblet Squats?',
#    'Which muscle groups are activated during Goblet Squats?',
#    'How should I position the kettlebell while performing Goblet Squats?',
#    'What type of exercise are Goblet Squats classified as?',
#    'Which part of the body does Goblet Squats primarily target?']},
#  20: {'questions': ['What is the starting position for the Glute Bridge exercise?',
#    'Which muscle groups does the Glute Bridge target?',
#    'What type of activity is the Glute Bridge classified as?',
#    'Do I need any equipment to perform the Glute Bridge?',
#    'How do I properly execute the lift during the Glute Bridge?']},
#  21: {'questions': ['What equipment do I need to perform the Overhead Tricep Extension?',
#    'Which muscle group is primarily targeted during this exercise?',
#    'Can you explain the proper technique for the Overhead Tricep Extension?',
#    'Is the Overhead Tricep Extension considered a strength exercise?',
#    'What part of the body does the Overhead Tricep Extension focus on?']},
#  22: {'questions': ['What is the correct starting position for the Side Plank exercise?',
#    'Which muscle groups are primarily activated during the Side Plank?',
#    'Do I need any equipment to perform the Side Plank?',
#    'How should I position my body when holding the Side Plank?',
#    'What type of exercise is the Side Plank classified as?']},
#  23: {'questions': ['What is the primary muscle group targeted by Cable Flyes?',
#    'Can you describe the stance I should take while performing Cable Flyes?',
#    'Should my elbows be straight or slightly bent during Cable Flyes?',
#    'What type of equipment do I need to perform Cable Flyes?',
#    'Is Cable Flyes considered a push or pull exercise?']},
#  24: {'questions': ['What type of activity is Step-Ups classified as?',
#    'What muscle groups are activated during Step-Ups?',
#    'Do I need any equipment to perform Step-Ups?',
#    'Can you provide instructions for properly performing Step-Ups?',
#    'Which body part primarily benefits from Step-Ups?']},
#  25: {'questions': ['What equipment do I need to perform Barbell Rows?',
#    'Which muscles are primarily worked during Barbell Rows?',
#    'Can you describe the stance I should use for this exercise?',
#    'What is the correct form for rowing the barbell towards my torso?',
#    'Is Barbell Rows focused on the upper body or lower body?']},
#  26: {'questions': ['What equipment do I need for the Chest Press exercise?',
#    'Which muscle groups are primarily activated during the Chest Press?',
#    'Can you explain how to perform the Chest Press correctly?',
#    'What part of the body does the Chest Press target?',
#    'Is the Chest Press considered a push-type exercise?']},
#  27: {'questions': ['What is the primary muscle group worked during box jumps?',
#    'Do I need any equipment to perform box jumps?',
#    'How should I land when I jump onto the box?',
#    'Can box jumps be considered both a cardio and strength exercise?',
#    'What body part does the box jump primarily target?']},
#  28: {'questions': ['What are the main muscle groups worked during Hanging Leg Raises?',
#    'What equipment do I need to perform Hanging Leg Raises?',
#    'Can you guide me on how to execute Hanging Leg Raises correctly?',
#    'What type of exercise is Hanging Leg Raises classified as?',
#    'Is there a specific position I should hold my legs in while doing Hanging Leg Raises?']},
#  29: {'questions': ["What is the primary focus of the Farmer's Walk exercise?",
#    "What type of equipment is required for the Farmer's Walk?",
#    "Which muscle groups are engaged during the Farmer's Walk?",
#    "Can the Farmer's Walk be classified as strength or cardio?",
#    "What is the correct form to maintain while performing the Farmer's Walk?"]},
#  30: {'questions': ['What is the primary muscle group targeted by calf raises?',
#    'What are the instructions for performing calf raises?',
#    'Is any equipment needed for calf raises?',
#    'How does the calf raise exercise affect the lower body?',
#    'What type of exercise is calf raises considered to be?']},
#  31: {'questions': ['What type of exercise is Battle Ropes classified as?',
#    'Which equipment do I need for the Battle Ropes exercise?',
#    'What specific body parts will get activated while doing Battle Ropes?',
#    'Can you explain how to properly perform the Battle Ropes exercise?',
#    'What muscle groups will I be targeting when using Battle Ropes?']},
#  32: {'questions': ['What is the primary body part targeted by medicine ball slams?',
#    'What equipment do I need to perform medicine ball slams?',
#    'Can you describe how to properly execute a medicine ball slam?',
#    'What muscle groups are activated while doing medicine ball slams?',
#    'Is this exercise classified as cardio, strength, or both?']},
#  33: {'questions': ['What is the main purpose of performing the Dumbbell Deadlift exercise?',
#    'Which muscle groups are primarily targeted when doing the Dumbbell Deadlift?',
#    'Can you describe the correct stance for the Dumbbell Deadlift?',
#    'What is the proper form for lowering and lifting the weights during a Dumbbell Deadlift?',
#    'Is the Dumbbell Deadlift considered a pull exercise, and why?']},
#  34: {'questions': ['What equipment do I need to perform the Push Press exercise?',
#    'Which body parts are targeted during the Push Press?',
#    'Can you explain the proper form for executing the Push Press?',
#    'How can I utilize my legs effectively during the Push Press?',
#    'What muscle groups are primarily worked when doing the Push Press?']},
#  35: {'questions': ['What muscles are primarily worked during a treadmill run?',
#    'What type of activity is a treadmill run categorized as?',
#    'Can you explain how to adjust the treadmill for this exercise?',
#    'What body part does the treadmill run primarily target?',
#    'Is the treadmill run considered a pushing or pulling exercise?']},
#  36: {'questions': ['What is the primary exercise for targeting the pectorals and triceps?',
#    'Which equipment is needed for performing the incline dumbbell press?',
#    'What position should I be in to execute the incline dumbbell press correctly?',
#    'How do I perform the incline dumbbell press correctly?',
#    'Which muscle groups are engaged during the incline dumbbell press?']},
#  37: {'questions': ['What equipment do I need for Renegade Rows?',
#    'Which muscle groups are primarily targeted by this exercise?',
#    'How do I properly begin the Renegade Rows?',
#    'What body parts are engaged during the Renegade Rows?',
#    'Is the Renegade Rows exercise considered a strength training activity?']},
#  38: {'questions': ['What is the primary muscle group targeted during the Leg Press exercise?',
#    'Can you describe the proper stance for my feet on the Leg Press machine?',
#    'What type of equipment do I need to perform the Leg Press exercise?',
#    'Is the Leg Press considered a push type of exercise?',
#    'Which body part does the Leg Press primarily work on?']},
#  39: {'questions': ['What equipment do I need for the Cable Tricep Pushdown exercise?',
#    'How should I position myself while performing the Cable Tricep Pushdown?',
#    'Which muscle groups does the Cable Tricep Pushdown primarily target?',
#    'What is the movement direction during the Cable Tricep Pushdown?',
#    'What are the instructions for executing the Cable Tricep Pushdown correctly?']},
#  40: {'questions': ['What muscles are primarily worked during the Single-Leg Deadlift?',
#    'What is the proper stance to take when performing a Single-Leg Deadlift?',
#    'What type of equipment do I need to perform the Single-Leg Deadlift?',
#    'How do I hold the dumbbell while executing the Single-Leg Deadlift?',
#    'What body part does the Single-Leg Deadlift primarily target?']},
#  41: {'questions': ['What is the primary muscle group worked during inverted rows?',
#    'Do I need any equipment to perform inverted rows, or can I use just my body weight?',
#    'What is the proper form for executing inverted rows effectively?',
#    'Is this exercise suitable for beginners, or should I have prior experience with strength training?',
#    'How do inverted rows compare to other upper body exercises?']},
#  42: {'questions': ['What position should I stand in when performing the Pallof Press?',
#    'At what height should the cable handle be set for this exercise?',
#    'Which muscle groups are primarily targeted by the Pallof Press?',
#    'How do I perform the Pallof Press to effectively engage my core?',
#    'Should I be resisting any movement while pushing the handle out?']},
#  43: {'questions': ['What muscles are primarily activated during the Kettlebell Deadlift?',
#    'Can you describe the positioning of my feet while performing the Kettlebell Deadlift?',
#    'What equipment do I need to perform the Kettlebell Deadlift?',
#    'How do I properly lift the kettlebell from the ground during this exercise?',
#    'Which type of exercise is the Kettlebell Deadlift classified as?']},
#  44: {'questions': ['What are Hanging Knee Tucks primarily working on in terms of muscle groups?',
#    'What equipment do I need to perform Hanging Knee Tucks?',
#    'Can you explain the steps for executing Hanging Knee Tucks properly?',
#    'What type of exercise are Hanging Knee Tucks classified as?',
#    'Which body part is primarily targeted by Hanging Knee Tucks?']},
#  45: {'questions': ['What muscles are primarily targeted when performing Resistance Band Pull Aparts?',
#    'What equipment do I need to do Resistance Band Pull Aparts?',
#    'Can you explain the correct position of my arms during the exercise?',
#    'Is this exercise suitable for strengthening my upper body?',
#    'How do I properly execute the pulling motion with the resistance band?']},
#  46: {'questions': ['What is the proper stance for Bulgarian Split Squats?',
#    'How do I ensure my front thigh is parallel to the floor during this exercise?',
#    'Which muscle groups are primarily targeted with Bulgarian Split Squats?',
#    'Is bodyweight sufficient for Bulgarian Split Squats, or do I need additional equipment?',
#    'Can you explain the movement pattern during the Bulgarian Split Squats?']},
#  47: {'questions': ['What is the correct starting position for the Seated Shoulder Press exercise?',
#    'Which muscles are primarily worked during the Seated Shoulder Press?',
#    'What type of equipment do I need to perform the Seated Shoulder Press?',
#    'Can you tell me the steps to properly execute the Seated Shoulder Press?',
#    'Is the Seated Shoulder Press classified as a push or pull exercise?']},
#  48: {'questions': ['What equipment do I need to perform Incline Push-Ups?',
#    'Which parts of my body do Incline Push-Ups target?',
#    'Can you describe the proper form for Incline Push-Ups?',
#    'What type of activity are Incline Push-Ups classified as?',
#    'How do I correctly position my hands for Incline Push-Ups?']},
#  49: {'questions': ['What is the proper setup for performing hip thrusts with a barbell?',
#    'Which muscle groups are primarily targeted during hip thrusts?',
#    'Can you explain the correct technique for lifting my hips in this exercise?',
#    'What type of equipment do I need to perform hip thrusts effectively?',
#    'Is this exercise considered a push movement or a pull movement?']},
#  50: {'questions': ['What is the proper stance for performing a Barbell Curl?',
#    'How do I grip the barbell for this exercise?',
#    'Which muscles are targeted during the Barbell Curl?',
#    'What is the movement process of a Barbell Curl?',
#    'What type of exercise is the Barbell Curl classified as?']},
#  51: {'questions': ['What is the primary equipment needed for the Cable Row exercise?',
#    'Which body part does the Cable Row primarily target?',
#    'Can you explain the correct sitting position for the Cable Row?',
#    'What muscles are engaged during the Cable Row?',
#    'How do I properly perform the pulling motion in the Cable Row?']},
#  52: {'questions': ['What is the starting position for Plank Shoulder Taps?',
#    'Which muscle groups are primarily targeted during this exercise?',
#    'How do I maintain stability while tapping my shoulder?',
#    'Is any equipment required for Plank Shoulder Taps?',
#    'What type of exercise is the Plank Shoulder Taps classified as?']},
#  53: {'questions': ['What equipment do I need for the Dumbbell Lateral Raise?',
#    'What specific body part does this exercise target?',
#    'Can you describe the proper form for performing a Dumbbell Lateral Raise?',
#    'What type of exercise is the Dumbbell Lateral Raise categorized as?',
#    'Which muscle groups are activated during this exercise?']},
#  54: {'questions': ['What is the Wall Sit exercise primarily targeting in terms of muscle groups?',
#    'How should I position my feet when performing a Wall Sit?',
#    'What angle should my knees be at during the Wall Sit?',
#    'Is any equipment necessary for the Wall Sit exercise?',
#    'What type of activity is the Wall Sit classified as?']},
#  55: {'questions': ['What is the Spider Plank exercise primarily targeting?',
#    'What muscle groups are activated during the Spider Plank?',
#    'Can I perform the Spider Plank without any equipment?',
#    'What is the starting position for the Spider Plank?',
#    'How do I execute the movement in the Spider Plank?']},
#  56: {'questions': ['What stance should I have while performing the Sumo Deadlift?',
#    'Which muscle groups are activated during the Sumo Deadlift?',
#    'How should I position my hands when grasping the barbell?',
#    'What type of equipment do I need for the Sumo Deadlift?',
#    'What is the proper technique for lifting the barbell in this exercise?']},
#  57: {'questions': ['What position should I start in for the Single Arm Dumbbell Row?',
#    'Which muscle groups are primarily worked during this exercise?',
#    'How should I hold the dumbbell while performing the exercise?',
#    'What is the main focus of the Single Arm Dumbbell Row in terms of movement type?',
#    'Do I need any special equipment besides a dumbbell for this exercise?']},
#  58: {'questions': ['What muscles are primarily activated during the Kettlebell Clean and Press?',
#    'Can you explain the proper form for performing a Kettlebell Clean and Press?',
#    'Is the Kettlebell Clean and Press suitable for a full body workout?',
#    'What type of movement is the Kettlebell Clean and Press classified as?',
#    'How do I incorporate the Kettlebell Clean and Press into my strength training routine?']},
#  59: {'questions': ['What is the primary type of exercise associated with jump rope?',
#    'Which body parts are primarily engaged when performing jump rope?',
#    'What equipment do I need to perform jump rope exercises?',
#    'Can jump rope be classified as a push exercise?',
#    'How do I correctly perform jump rope to maintain a steady rhythm?']},
#  60: {'questions': ['What is the proper form for performing a side lunge?',
#    'Which muscles are targeted when doing a side lunge?',
#    'Do I need any equipment to do a side lunge?',
#    'Can you explain the movement involved in a side lunge?',
#    'Is the side lunge primarily a strength exercise for the lower body?']},
#  61: {'questions': ['What is the Machine Chest Fly exercise primarily designed to target?',
#    'Can I perform the Machine Chest Fly using free weights instead of a machine?',
#    'What steps should I follow to execute the Machine Chest Fly correctly?',
#    'What muscle groups do I activate when performing the Machine Chest Fly?',
#    'Is the Machine Chest Fly considered a push or pull exercise?']},
#  62: {'questions': ['What muscles are primarily targeted during the Hack Squat exercise?',
#    'Can you describe the proper stance to use while performing a Hack Squat on the machine?',
#    'How should I position my feet when using the Hack Squat machine?',
#    'What is the correct movement pattern for executing a Hack Squat?',
#    'Is the Hack Squat more beneficial for strengthening the lower body compared to other exercises?']},
#  63: {'questions': ['What is the correct position for my feet during decline push-ups?',
#    'Which muscle groups are primarily worked by decline push-ups?',
#    'How do I perform a decline push-up correctly?',
#    'What type of equipment do I need for decline push-ups?',
#    'Is the decline push-up suitable for improving upper body strength?']},
#  64: {'questions': ['What equipment do I need for the Band Face Pull exercise?',
#    'Which muscle groups are activated when performing the Band Face Pull?',
#    'Can you explain the proper way to perform the Band Face Pull?',
#    'What part of the body does the Band Face Pull primarily target?',
#    'Is the Band Face Pull considered a strength or cardio exercise?']},
#  65: {'questions': ['What is the primary muscle group targeted by the Ab Wheel Rollout?',
#    'Can you explain the initial position for performing the Ab Wheel Rollout?',
#    'What kind of equipment do I need for the Ab Wheel Rollout exercise?',
#    'How do I maintain stability while rolling the wheel forward?',
#    'Is the Ab Wheel Rollout considered a push type of exercise?']},
#  66: {'questions': ['What position should I be in to perform Side Leg Raises effectively?',
#    'Which leg do I need to lift when doing this exercise?',
#    'What muscles are engaged during Side Leg Raises?',
#    'Are any equipment required to perform Side Leg Raises?',
#    'What type of exercise is Side Leg Raises classified as?']},
#  67: {'questions': ['What equipment do I need for the Romanian Deadlift?',
#    'Which muscle groups are targeted during this exercise?',
#    'Can you describe the proper form for performing a Romanian Deadlift?',
#    'Is the Romanian Deadlift primarily a pulling or pushing exercise?',
#    'Which part of my body will feel the most strain while doing this exercise?']},
#  68: {'questions': ['What is the main focus of the Arnold Press exercise?',
#    'Which muscle groups does the Arnold Press work on?',
#    'What equipment do I need to perform the Arnold Press?',
#    'Can you explain the proper technique for the Arnold Press?',
#    'Is the Arnold Press suitable for beginners?']},
#  69: {'questions': ['What is the primary muscle group targeted by the Landmine Press exercise?',
#    'Which type of equipment do I need to perform the Landmine Press?',
#    'What is the proper technique for pressing the barbell during the Landmine Press?',
#    'Is the Landmine Press considered a push exercise?',
#    'What body part does the Landmine Press focus on?']},
#  70: {'questions': ['What are tuck jumps primarily targeting in terms of muscle activation?',
#    'Can you explain the correct technique for performing tuck jumps?',
#    'What equipment do I need to do tuck jumps?',
#    'Are tuck jumps considered a strength or cardio exercise?',
#    'How should I land after completing a tuck jump?']},
#  71: {'questions': ['What is the primary muscle group targeted by the Windshield Wipers exercise?',
#    'Can you describe the initial position I should start in for doing Windshield Wipers?',
#    'Is any special equipment needed to perform Windshield Wipers?',
#    'What type of exercise is Windshield Wipers classified as?',
#    'How should I move my legs while performing the Windshield Wipers?']},
#  72: {'questions': ['What equipment do I need to perform Dumbbell Shrugs?',
#    'Which muscle group is primarily targeted by Dumbbell Shrugs?',
#    'Can you explain the proper stance for doing Dumbbell Shrugs?',
#    'What is the correct motion for Dumbbell Shrugs?',
#    'Is Dumbbell Shrugs classified as a strength exercise?']},
#  73: {'questions': ['What muscles are primarily activated during the Sled Push exercise?',
#    'What type of equipment do I need to perform the Sled Push?',
#    'Can I integrate the Sled Push into both cardio and strength workouts?',
#    'What is the correct form I should maintain while pushing the sled?',
#    'Is the Sled Push suitable for full body workouts?']},
#  74: {'questions': ['What equipment do I need to perform a Cable Bicep Curl?',
#    'Which muscle groups are primarily targeted by the Cable Bicep Curl?',
#    'Can you describe the correct stance to adopt when executing this exercise?',
#    'What is the starting position for a Cable Bicep Curl?',
#    'How do I execute the movement for the Cable Bicep Curl correctly?']},
#  75: {'questions': ['What is the primary muscle group worked during the Dumbbell Kickback?',
#    'Can I perform the Dumbbell Kickback without any equipment?',
#    'How should my body be positioned while doing the Dumbbell Kickback?',
#    'What type of exercise is the Dumbbell Kickback classified as?',
#    'How do I properly execute the movement for the Dumbbell Kickback?']},
#  76: {'questions': ['What is the primary muscle group targeted by Flutter Kicks?',
#    'Do I need any equipment to perform Flutter Kicks?',
#    'How do I properly execute Flutter Kicks?',
#    'In what position should I start when doing Flutter Kicks?',
#    'What is the main focus of Flutter Kicks?']},
#  77: {'questions': ['What type of activity is High Knees classified as?',
#    'Which muscle groups are primarily activated during High Knees?',
#    'Do I need any equipment to perform High Knees?',
#    'Can you describe how to properly perform High Knees?',
#    'What part of the body does High Knees work out?']},
#  78: {'questions': ['What type of physical activity do Sledgehammer Slams fall under?',
#    'What equipment do I need to perform Sledgehammer Slams?',
#    'Which muscle groups are primarily activated during Sledgehammer Slams?',
#    'Can you explain the proper technique for executing Sledgehammer Slams?',
#    'Is this exercise primarily for cardio, strength, or both?']},
#  79: {'questions': ['What equipment do I need to perform Lateral Step-Ups?',
#    'Which muscle groups are activated during Lateral Step-Ups?',
#    'Can you explain the steps involved in executing Lateral Step-Ups?',
#    'Is Lateral Step-Ups considered a strength exercise?',
#    'Which body part primarily gets worked with Lateral Step-Ups?']},
#  80: {'questions': ['What is the primary muscle group targeted by the Cable Chest Press?',
#    'What type of exercise is the Cable Chest Press classified as?',
#    'What equipment do I need to perform the Cable Chest Press?',
#    'Can you describe the starting position for the Cable Chest Press?',
#    'Which body part does the Cable Chest Press primarily focus on?']},
#  81: {'questions': ['What muscles does the TRX Rows exercise target specifically?',
#    'Can you explain the correct posture I should maintain while performing TRX Rows?',
#    'How do I properly grip the handles during TRX Rows?',
#    'What type of exercise is TRX Rows classified as?',
#    'Is TRX Rows primarily for my upper body strength?']},
#  82: {'questions': ['What is the main equipment needed for Medicine Ball Russian Twists?',
#    'Which muscles are primarily targeted during this exercise?',
#    'Can you explain how to properly perform a Medicine Ball Russian Twist?',
#    'What body part does the Medicine Ball Russian Twist mainly focus on?',
#    'Is the Medicine Ball Russian Twist considered a strength exercise?']},
#  83: {'questions': ['What is the Pendlay Row specifically used for in strength training?',
#    'Which equipment do I need to perform the Pendlay Row?',
#    'Can you describe the correct form for the Pendlay Row?',
#    'Which muscle groups are primarily engaged while doing the Pendlay Row?',
#    'What type of exercise is the Pendlay Row classified as: a push or a pull?']},
#  84: {'questions': ['What muscles are targeted when performing the Side Plank with Leg Lift?',
#    'How should I position my body during the Side Plank with Leg Lift?',
#    'Is any special equipment required for the Side Plank with Leg Lift?',
#    'What type of exercise is the Side Plank with Leg Lift classified as?',
#    'What is the main focus of the Side Plank with Leg Lift in terms of body parts?']},
#  85: {'questions': ['What is the primary muscle group targeted during the Hip Abduction exercise?',
#    'How do I perform the Hip Abduction on the machine?',
#    'Is the Hip Abduction considered a strength exercise?',
#    'What type of equipment do I need for the Hip Abduction?',
#    'Which body part does the Hip Abduction focus on?']},
#  86: {'questions': ['What type of exercise is the Dumbbell Front Raise?',
#    'Which body part does the Dumbbell Front Raise target?',
#    'What equipment do I need to perform the Dumbbell Front Raise?',
#    'How should my hands be positioned when starting the Dumbbell Front Raise?',
#    'What is the main muscle group activated during the Dumbbell Front Raise?']},
#  87: {'questions': ['What muscles do chin-ups primarily target?',
#    'How should I grip the bar when performing chin-ups?',
#    'Can you describe the movement involved in chin-ups?',
#    'What type of equipment do I need to perform chin-ups?',
#    'Is chin-ups an upper body or lower body exercise?']},
#  88: {'questions': ['What is the Box Squat exercise primarily targeting in terms of muscle groups?',
#    'Can you describe the setup required for performing a Box Squat?',
#    'What is the main equipment needed to perform a Box Squat?',
#    'How do I correctly perform a Box Squat?',
#    'Is the Box Squat considered a push exercise or a pull exercise?']},
#  89: {'questions': ['What type of physical activity does Battle Rope Waves fall under?',
#    'Which body parts are primarily worked during Battle Rope Waves?',
#    'What specific equipment do I need to perform Battle Rope Waves?',
#    'How do I properly execute the Battle Rope Waves exercise?',
#    'What muscle groups will I activate when doing Battle Rope Waves?']},
#  90: {'questions': ['What are the primary muscles worked in the Zercher Squat?',
#    'How do I properly hold the barbell during a Zercher Squat?',
#    'What is the correct depth for the squat in this exercise?',
#    'Is the Zercher Squat considered a push or pull exercise?',
#    'What type of equipment do I need to perform the Zercher Squat?']},
#  91: {'questions': ['What type of exercise is a Walking Lunge?',
#    'Which equipment is needed for Walking Lunges?',
#    'What main body part does Walking Lunges target?',
#    'Can you describe the correct technique for performing a Walking Lunge?',
#    'What muscle groups are engaged when doing Walking Lunges?']},
#  92: {'questions': ['What type of exercise is the kettlebell snatch considered?',
#    'Which body parts are primarily worked when performing the kettlebell snatch?',
#    'Can you explain the main movement of the kettlebell snatch?',
#    'What type of equipment do I need to perform a kettlebell snatch?',
#    'Is the kettlebell snatch primarily a pushing or pulling exercise?']},
#  93: {'questions': ['What is the primary muscle group targeted by the Single-Leg Glute Bridge exercise?',
#    'Can the Single-Leg Glute Bridge be performed without any equipment?',
#    'What position should my legs be in while doing the Single-Leg Glute Bridge?',
#    'What type of exercise is the Single-Leg Glute Bridge categorized as?',
#    'How do you execute the movement of lifting your hips during the Single-Leg Glute Bridge?']},
#  94: {'questions': ['What are TRX Push-Ups and how are they performed?',
#    'Which muscle groups are activated during TRX Push-Ups?',
#    'What equipment do I need to perform TRX Push-Ups?',
#    'Is TRX Push-Ups suitable for strengthening the upper body?',
#    'What is the correct position for my body while doing TRX Push-Ups?']},
#  95: {'questions': ['What is the primary muscle group activated by the Machine Leg Curl exercise?',
#    'How should I position myself on the leg curl machine?',
#    'Can you describe the movement involved in the Machine Leg Curl?',
#    'What is the primary body part targeted by this exercise?',
#    'Is the Machine Leg Curl considered a strength or cardio exercise?']},
#  96: {'questions': ['What muscles are primarily worked during the Incline Bench Press?',
#    'Could you explain the setup for performing the Incline Bench Press?',
#    'What type of equipment do I need for the Incline Bench Press?',
#    'What body part does the Incline Bench Press primarily target?',
#    'What is the correct movement technique for the Incline Bench Press?']},
#  97: {'questions': ['What equipment do I need for the Resistance Band Deadlift?',
#    'Which muscle groups are activated when performing the Resistance Band Deadlift?',
#    'Can you describe the proper stance for this exercise?',
#    'What is the main movement involved in the Resistance Band Deadlift?',
#    'How do I position my body before lifting the resistance band?']},
#  98: {'questions': ['What equipment do I need for the Decline Bench Press exercise?',
#    'Which muscle groups are activated when performing the Decline Bench Press?',
#    'Can you describe the proper form for the Decline Bench Press?',
#    'What is the primary type of activity for the Decline Bench Press?',
#    'How should I position my body on the decline bench during this exercise?']},
#  99: {'questions': ['What muscles are primarily worked during the Dumbbell Step-Up exercise?',
#    'What type of activity is the Dumbbell Step-Up classified as?',
#    'Do I need any specific equipment to perform the Dumbbell Step-Up?',
#    'Can you explain the proper form for executing a Dumbbell Step-Up?',
#    'Is the Dumbbell Step-Up considered a push or pull exercise?']},
#  100: {'questions': ['What type of exercise is the Cable Lateral Raise?',
#    'Which equipment do I need to perform the Cable Lateral Raise?',
#    'What body part does the Cable Lateral Raise primarily target?',
#    'Can you explain how to properly perform the Cable Lateral Raise?',
#    'What muscle groups are activated during the Cable Lateral Raise?']},
#  101: {'questions': ['What type of exercise is a Reverse Lunge?',
#    'What equipment do I need to perform a Reverse Lunge?',
#    'Which part of the body does the Reverse Lunge primarily target?',
#    'What are the main muscle groups activated during a Reverse Lunge?',
#    'Can you explain how to properly execute a Reverse Lunge?']},
#  102: {'questions': ['What muscles are activated when performing Toe Touches?',
#    'How should I position my legs during the Toe Touches exercise?',
#    'Is any equipment needed for Toe Touches?',
#    'Can you describe the starting position for Toe Touches?',
#    'What type of exercise is Toe Touches classified as?']},
#  103: {'questions': ['What muscles are primarily targeted during the Machine Leg Extension exercise?',
#    'How should I position myself on the leg extension machine?',
#    'What is the correct motion for the Machine Leg Extension?',
#    'Is the Machine Leg Extension considered a push or pull type exercise?',
#    'Which body part does the Machine Leg Extension focus on?']},
#  104: {'questions': ['What is the primary muscle group worked by the Dumbbell Pullover?',
#    'Can you explain how to perform the Dumbbell Pullover correctly?',
#    'What type of equipment do I need for the Dumbbell Pullover exercise?',
#    'Is the Dumbbell Pullover considered a strength exercise or a cardio workout?',
#    'Which body part does the Dumbbell Pullover primarily target?']},
#  105: {'questions': ['What specific muscle group does the Barbell Shrug target?',
#    'Can you describe the starting position for performing a Barbell Shrug?',
#    'How should I position my feet while doing the Barbell Shrug?',
#    'What is the correct movement for the shoulders during the Barbell Shrug?',
#    'Is it necessary to use a barbell for this exercise, or can I use other equipment?']},
#  106: {'questions': ['What muscles are worked during the T-Bar Row exercise?',
#    'What type of equipment do I need for the T-Bar Row?',
#    'What is the correct stance when performing the T-Bar Row?',
#    'How do I execute the rowing motion in the T-Bar Row?',
#    'Is the T-Bar Row considered a strength or cardio exercise?']},
#  107: {'questions': ['What muscles are primarily worked by the Bulgarian Deadlift?',
#    'What equipment do I need to perform the Bulgarian Deadlift?',
#    'Can you describe the stance for the Bulgarian Deadlift?',
#    'Is the Bulgarian Deadlift a push or pull exercise?',
#    'Which body part does the Bulgarian Deadlift target?']},
#  108: {'questions': ['What is the primary focus of the Pistol Squat exercise?',
#    'Can I perform the Pistol Squat without any equipment?',
#    'Which muscle groups are worked during the Pistol Squat?',
#    'What are the steps involved in performing a Pistol Squat correctly?',
#    'Is the Pistol Squat primarily a push or pull exercise?']},
#  109: {'questions': ['What is the primary muscle group targeted by the Seated Leg Curl exercise?',
#    'Can you describe the main instruction for performing the Seated Leg Curl?',
#    'What type of equipment is needed to perform the Seated Leg Curl?',
#    'Is the Seated Leg Curl considered a strength activity or a cardio activity?',
#    'Which body part does the Seated Leg Curl primarily work on?']},
#  110: {'questions': ['What is the main purpose of the Russian Kettlebell Swing exercise?',
#    'Which equipment do I need to perform the Russian Kettlebell Swing?',
#    'What body parts are primarily targeted during this exercise?',
#    'Can you explain the correct technique for executing a kettlebell swing?',
#    'Is the Russian Kettlebell Swing more focused on cardio or strength training?']},
#  111: {'questions': ['What equipment do I need to perform the Incline Dumbbell Curl exercise?',
#    'Which muscle groups are targeted by the Incline Dumbbell Curl?',
#    'What is the proper position to start the Incline Dumbbell Curl?',
#    'Can you describe the movement involved in the Incline Dumbbell Curl?',
#    'Is the Incline Dumbbell Curl considered a pull type exercise?']},
#  112: {'questions': ['What is the proper position for performing decline sit-ups?',
#    'Which muscle groups are primarily targeted during decline sit-ups?',
#    'What type of equipment do I need for decline sit-ups?',
#    'How should I execute the movement during decline sit-ups?',
#    'Is this exercise considered a strength activity?']},
#  113: {'questions': ['What is the starting position for Side Plank Dips?',
#    'Which muscle groups are primarily activated during this exercise?',
#    'How do I properly perform the movement of lowering and lifting my hips in a Side Plank Dip?',
#    'What type of equipment do I need to perform Side Plank Dips?',
#    'Is the Side Plank Dips exercise mainly for core strength?']},
#  114: {'questions': ['What is the primary equipment needed for the Single Arm Kettlebell Swing?',
#    'Which muscle groups are engaged during the exercise?',
#    'How should I position the kettlebell while performing the swing?',
#    'What is the correct movement to initiate the Single Arm Kettlebell Swing?',
#    'Is this exercise primarily a strength-based activity?']},
#  115: {'questions': ['What muscles are targeted by jumping squats?',
#    'How do you properly execute a jumping squat?',
#    'Is any equipment needed for jumping squats?',
#    'What type of workout does jumping squats fall under?',
#    'Which body part is primarily worked during jumping squats?']},
#  116: {'questions': ['What is the primary purpose of the Cable Chest Fly exercise?',
#    'Which part of the body does the Cable Chest Fly mainly target?',
#    'What type of equipment is required to perform the Cable Chest Fly?',
#    'Can you describe the correct starting position for the Cable Chest Fly?',
#    'What movement should be performed after bringing the handles together in front?']},
#  117: {'questions': ['What is the correct way to position the dumbbell for a tricep extension?',
#    'Which body part is primarily targeted during the dumbbell tricep extension?',
#    'How do I perform the movement correctly for maximum effectiveness?',
#    'What type of exercise is the dumbbell tricep extension classified as?',
#    'What type of equipment do I need for this exercise?']},
#  118: {'questions': ['What equipment do I need for the Leg Curl exercise?',
#    'Which part of the body is primarily worked by the Leg Curl?',
#    'Can you explain the proper technique for performing a Leg Curl?',
#    'Is the Leg Curl considered a strength training exercise?',
#    'What muscle group is targeted when doing the Leg Curl?']},
#  119: {'questions': ['What is the starting position for the One-Arm Push-Up?',
#    'Which muscle groups are activated during the One-Arm Push-Up?',
#    'What body part does the One-Arm Push-Up primarily target?',
#    'What should I do after lowering my body in the One-Arm Push-Up?',
#    'Is any equipment required to perform the One-Arm Push-Up?']},
#  120: {'questions': ['What is the proper way to perform the Machine Shoulder Press?',
#    'Which muscle groups are primarily worked during the Machine Shoulder Press?',
#    'What type of equipment is needed for the Machine Shoulder Press?',
#    'Is the Machine Shoulder Press considered a push exercise?',
#    'What part of the body does the Machine Shoulder Press target?']},
#  121: {'questions': ['What stance should I take when performing the sumo squat?',
#    'How low should I lower my hips during the exercise?',
#    'What muscles are primarily activated when doing sumo squats?',
#    'Is any equipment required for this exercise?',
#    'What type of exercise classification does sumo squat fall under?']},
#  122: {'questions': ['What is the primary equipment needed for the Resistance Band Squat?',
#    'Which muscle groups are targeted during the Resistance Band Squat?',
#    'Can you describe how to position my feet during this exercise?',
#    'What body part does the Resistance Band Squat primarily focus on?',
#    'Is the Resistance Band Squat considered a strength training exercise?']},
#  123: {'questions': ['What is the correct starting position for a One-Legged Squat?',
#    'Which muscles are primarily worked during the One-Legged Squat?',
#    'How do I perform the One-Legged Squat correctly?',
#    'Do I need any equipment to do a One-Legged Squat?',
#    'Is the One-Legged Squat considered a strength exercise?']},
#  124: {'questions': ['What setup is required for the Landmine Row exercise?',
#    'Which muscle groups are primarily targeted when performing the Landmine Row?',
#    'Can you explain the correct technique for executing a Landmine Row?',
#    'Is there a specific type of barbell needed for the Landmine Row?',
#    'What body part does the Landmine Row mainly focus on?']},
#  125: {'questions': ['What is the starting position for the Superman Exercise?',
#    'Which muscle groups are primarily targeted by this exercise?',
#    'How do I perform the Superman Exercise correctly?',
#    'What type of equipment do I need for the Superman Exercise?',
#    'Is the Superman Exercise focused on strength training or cardio?']},
#  126: {'questions': ['What is the primary muscle group targeted during Dumbbell Flyes?',
#    'What type of exercise is Dumbbell Flyes classified as?',
#    'What equipment do I need to perform Dumbbell Flyes?',
#    'Can you describe the starting position for Dumbbell Flyes?',
#    'Is Dumbbell Flyes considered a push exercise?']},
#  127: {'questions': ['What is the main purpose of the Reverse Fly exercise?',
#    'Which muscle groups are primarily worked during the Reverse Fly?',
#    'Can I perform the Reverse Fly without using dumbbells?',
#    'How should I position my body while doing the Reverse Fly?',
#    'Is the Reverse Fly considered a pull exercise?']},
#  128: {'questions': ['What equipment do I need for Cable Kickbacks?',
#    'Which body parts are targeted during Cable Kickbacks?',
#    'Can you describe how to perform Cable Kickbacks correctly?',
#    'What muscle groups are activated when doing Cable Kickbacks?',
#    'Is Cable Kickbacks considered a strength exercise?']},
#  129: {'questions': ['How do I properly hold the kettlebell for the push press exercise?',
#    'Which muscles are targeted when performing the kettlebell push press?',
#    'Can you explain the steps for executing the kettlebell push press?',
#    'What body parts are primarily involved in the kettlebell push press?',
#    'Is it necessary to engage my legs during the kettlebell push press?']},
#  130: {'questions': ['What is the Dead Bug exercise and how is it performed?',
#    'Which muscles are targeted when performing the Dead Bug exercise?',
#    'Do I need any equipment to do the Dead Bug exercise?',
#    'What is the primary body part worked during the Dead Bug?',
#    'What should I focus on to maintain proper form during the Dead Bug?']},
#  131: {'questions': ['What muscles are primarily targeted by the Smith Machine Squat?',
#    'Can you describe the proper form for performing a Smith Machine Squat?',
#    'What type of exercise is the Smith Machine Squat classified as?',
#    'Is equipment necessary for the Smith Machine Squat, and if so, what type?',
#    'What body part does the Smith Machine Squat mainly work?']},
#  132: {'questions': ['What is the correct position on the hyperextension bench for the Reverse Hyperextension exercise?',
#    'Which muscle groups are primarily targeted by the Reverse Hyperextension?',
#    'How do I properly perform the movement of lifting my legs in this exercise?',
#    'Is the Reverse Hyperextension exercise suitable for strengthening my lower back?',
#    'What type of equipment do I need to perform the Reverse Hyperextension?']},
#  133: {'questions': ['What muscles are primarily activated during the Landmine Twist exercise?',
#    'What is the main equipment required to perform the Landmine Twist?',
#    'How should I position my core while doing the Landmine Twist?',
#    'What is the correct way to hold the barbell during this exercise?',
#    'In which direction do I rotate the barbell while performing the Landmine Twist?']},
#  134: {'questions': ['What body parts are primarily targeted by the Machine Row exercise?',
#    'Can you explain the proper positioning for the Machine Row?',
#    'What muscle groups are activated during the Machine Row?',
#    'Is the Machine Row considered a strength training exercise?',
# ...
#    'Is the Prone Leg Curl considered a strength training exercise?',
#    'Which body part does the Prone Leg Curl target?']},
#  165: {'questions': ['What is the Seated Dumbbell Press targeting in terms of muscle groups?',
#    'How should I position my dumbbells when starting the Seated Dumbbell Press?',
#    'What is the correct movement for the Seated Dumbbell Press?',
#    'Which part of the body does the Seated Dumbbell Press primarily work out?',
#    'Is the Seated Dumbbell Press considered a push or pull exercise?']},
#  166: {'questions': ['What is the proper starting position for the Weighted Plank exercise?',
#    'Which muscle groups are engaged during the Weighted Plank?',
#    'How do I ensure my body remains straight while holding the Weighted Plank?',
#    'What type of equipment is needed for the Weighted Plank exercise?',
#    'Is the Weighted Plank primarily a strength or cardio exercise?']},
#  167: {'questions': ['What is the main purpose of using the Step Mill exercise?',
#    'Which muscle groups are primarily targeted when using the Step Mill?',
#    'Can you explain how to perform the Step Mill exercise correctly?',
#    'Is the Step Mill considered a cardio workout?',
#    'What type of equipment is used for the Step Mill exercise?']},
#  168: {'questions': ['What equipment do I need to perform the Standing Resistance Band Row?',
#    'Which muscle groups are primarily worked by this exercise?',
#    'Can you explain the correct form for pulling the handles during this exercise?',
#    'What body part does the Standing Resistance Band Row focus on?',
#    'Is this exercise considered a strength or cardio workout?']},
#  169: {'questions': ['What is the primary focus of the Dumbbell Lunge exercise?',
#    'Which equipment is required to perform the Dumbbell Lunge?',
#    'How should the Dumbbell Lunge be executed step-by-step?',
#    'What muscle groups are targeted by the Dumbbell Lunge?',
#    'Is the Dumbbell Lunge classified as a push or pull exercise?']},
#  170: {'questions': ['What is the primary muscle group targeted by the Reverse Curl exercise?',
#    'What type of grip should I use when performing the Reverse Curl?',
#    'Do I need any equipment for the Reverse Curl, and if so, what kind?',
#    'How should my feet be positioned while doing the Reverse Curl?',
#    'Is the Reverse Curl focused on pulling or pushing movements?']},
#  171: {'questions': ['What is the primary muscle group targeted by the Banded Pull-Up exercise?',
#    'What type of equipment do I need to perform a Banded Pull-Up?',
#    'How do I properly set up for a Banded Pull-Up?',
#    'What body part does the Banded Pull-Up focus on strengthening?',
#    'What is the technique for executing a Banded Pull-Up correctly?']},
#  172: {'questions': ['What equipment do I need to perform the Cable Face Pull exercise?',
#    'Which muscle groups are primarily activated during the Cable Face Pull?',
#    'Can you explain how to properly execute the Cable Face Pull?',
#    'What type of activity is the Cable Face Pull categorized under?',
#    'Which part of the body does the Cable Face Pull specifically target?']},
#  173: {'questions': ['What equipment do I need to perform the Turkish Get-Up exercise?',
#    'Which muscle groups are activated when doing the Turkish Get-Up?',
#    'How should I position my body before starting the Turkish Get-Up?',
#    'What is the primary action involved in the Turkish Get-Up?',
#    'Is the Turkish Get-Up considered a strength or cardio exercise?']},
#  174: {'questions': ['What equipment do I need for Weighted Russian Twists?',
#    'Which muscles are activated during the Weighted Russian Twists exercise?',
#    'Can you explain the proper form for performing Weighted Russian Twists?',
#    'Is Weighted Russian Twists effective for strengthening my core?',
#    'What is the correct position for my legs when doing Weighted Russian Twists?']},
#  175: {'questions': ['What is the proper stance when performing the Cable Front Raise?',
#    'At what height should I raise the handle during the exercise?',
#    'Which muscles are primarily targeted by the Cable Front Raise?',
#    'What type of equipment is required for the Cable Front Raise?',
#    'Is the Cable Front Raise considered a push or pull exercise?']},
#  176: {'questions': ['What is the proper starting position for a reverse crunch?',
#    'Which muscle groups are primarily targeted during the reverse crunch?',
#    'How should I perform the movement of lifting my hips during the reverse crunch?',
#    'What type of exercise is a reverse crunch categorized as?',
#    'Do I need any equipment to perform a reverse crunch?']},
#  177: {'questions': ['What equipment do I need for the Cable Tricep Kickback exercise?',
#    'Which muscle group is primarily targeted by this exercise?',
#    'Can you describe the correct form for performing the Cable Tricep Kickback?',
#    'What type of activity is the Cable Tricep Kickback considered?',
#    'What is the starting position for the Cable Tricep Kickback?']},
#  178: {'questions': ['What is the Copenhagen Plank and how is it performed?',
#    'Which muscle groups are engaged during the Copenhagen Plank?',
#    'Do I need any equipment to perform the Copenhagen Plank?',
#    'What position should my legs be in while doing the Copenhagen Plank?',
#    'Is the Copenhagen Plank a strength or cardio exercise?']},
#  179: {'questions': ['What is the primary equipment used for the Smith Machine Incline Press?',
#    'Which muscle groups are primarily targeted during this exercise?',
#    'Can you describe the starting position for the Smith Machine Incline Press?',
#    'What type of exercise is the Smith Machine Incline Press categorized as?',
#    'What action should I perform with the bar during this exercise?']},
#  180: {'questions': ['What equipment do I need for the Cable Lat Pulldown exercise?',
#    'Which muscle groups are primarily worked during the Cable Lat Pulldown?',
#    'Can you explain the setup process for the Cable Lat Pulldown?',
#    'What is the proper way to grip the bar for this exercise?',
#    'How should I perform the movement during the Cable Lat Pulldown?']},
#  181: {'questions': ['What equipment do I need for the Cable Side Lunge exercise?',
#    'Which muscle groups does the Cable Side Lunge activate?',
#    'Can you explain the steps involved in performing a Cable Side Lunge?',
#    'Is the Cable Side Lunge primarily a strength exercise?',
#    'Which body part does the Cable Side Lunge focus on?']},
#  182: {'questions': ['What is the primary muscle group targeted by the Dumbbell Bent-Over Row?',
#    'How should I position my feet when performing this exercise?',
#    'What type of equipment do I need for the Dumbbell Bent-Over Row?',
#    'Can you describe the proper body position during the exercise?',
#    'Is the Dumbbell Bent-Over Row classified as a push or pull exercise?']},
#  183: {'questions': ['What is the primary focus of the Lateral Lunge exercise?',
#    'Which muscle groups are activated when performing Lateral Lunges?',
#    'How do I properly execute a Lateral Lunge?',
#    'Do I need any equipment to perform Lateral Lunges?',
#    'What type of activity classification does the Lateral Lunge fall under?']},
#  184: {'questions': ['What type of exercise is the Seated Machine Row?',
#    'Which muscle groups are primarily activated during the Seated Machine Row?',
#    'What should I do with my feet while using the Seated Machine Row?',
#    'Can you describe the starting position for the Seated Machine Row?',
#    'Is the Seated Machine Row primarily an upper body or lower body exercise?']},
#  185: {'questions': ['What position should I take on the decline bench for the Decline Russian Twist?',
#    'How should I move my torso during the Decline Russian Twist?',
#    'Which muscle groups are primarily targeted by the Decline Russian Twist exercise?',
#    'Is any equipment required for performing the Decline Russian Twist?',
#    'What is the main type of movement involved in the Decline Russian Twist?']},
#  186: {'questions': ['What is the Deadlift High Pull exercise primarily designed to work on?',
#    'What type of equipment do I need to perform the Deadlift High Pull?',
#    'Can you explain the steps involved in executing the Deadlift High Pull properly?',
#    'What muscle groups are activated during the Deadlift High Pull?',
#    'Is the Deadlift High Pull considered a strength exercise or a cardio exercise?']},
#  187: {'questions': ['What is the correct grip for the Reverse Grip Lat Pulldown exercise?',
#    'Which muscles are primarily targeted when performing the Reverse Grip Lat Pulldown?',
#    'Can you explain the proper sitting position for this exercise?',
#    'How should I return the bar after pulling it down to my chest?',
#    'What type of equipment do I need for the Reverse Grip Lat Pulldown?']},
#  188: {'questions': ['What equipment do I need to perform the Cable Lateral Lunge?',
#    'Which body parts are primarily targeted by this exercise?',
#    'Can you explain the steps for executing a Cable Lateral Lunge?',
#    'Is this exercise suitable for building strength in my lower body?',
#    'What muscle groups will I activate when doing the Cable Lateral Lunge?']},
#  189: {'questions': ['What is the starting position for a Pike Push-Up?',
#    'Which body parts are primarily worked during a Pike Push-Up?',
#    'What type of equipment is needed for performing a Pike Push-Up?',
#    'Can you explain how to correctly perform a Pike Push-Up?',
#    'Is the Pike Push-Up classified as a strength exercise?']},
#  190: {'questions': ['What muscles are primarily worked by the One-Arm Dumbbell Snatch exercise?',
#    'Can you describe the starting position for the One-Arm Dumbbell Snatch?',
#    'Is the One-Arm Dumbbell Snatch considered a strength exercise?',
#    'What type of equipment do I need to perform the One-Arm Dumbbell Snatch?',
#    'How should I perform the motion of the One-Arm Dumbbell Snatch?']},
#  191: {'questions': ['What equipment do I need to perform the Cable Front Squat effectively?',
#    'Which muscle groups are primarily activated during the Cable Front Squat exercise?',
#    'Can you describe the correct stance and positioning for this exercise?',
#    'What is the proper way to hold the rope handle while doing the Cable Front Squat?',
#    'Is the Cable Front Squat suitable for beginners, and what should they keep in mind?']},
#  192: {'questions': ['What is the primary equipment used for the Tire Flip exercise?',
#    'Which muscles are primarily activated during the Tire Flip?',
#    'Can you describe the initial position for performing the Tire Flip?',
#    'What type of activity is the Tire Flip classified under?',
#    'Is the Tire Flip considered a full body workout?']},
#  193: {'questions': ['What is the primary muscle group worked during the Smith Machine Calf Raise?',
#    'What equipment do I need to perform the Smith Machine Calf Raise?',
#    'Can you describe the starting position for this exercise?',
#    'What action do I take after raising my heels in the Smith Machine Calf Raise?',
#    'Is this exercise categorized as a strength activity, and if so, what type?']},
#  194: {'questions': ['What is the starting position for the Pistol Squat to Box exercise?',
#    'Which muscles are primarily worked during the Pistol Squat to Box?',
#    'What equipment is needed to perform the Pistol Squat to Box?',
#    'Can the Pistol Squat to Box be performed without any equipment?',
#    'What is the main movement involved in the Pistol Squat to Box exercise?']},
#  195: {'questions': ['What is the Standing Chest Fly and what type of activity is it?',
#    'Which equipment do I need to perform the Standing Chest Fly?',
#    'What part of the body does the Standing Chest Fly primarily target?',
#    'Can you explain how to properly perform the Standing Chest Fly?',
#    'What muscle groups are activated when doing the Standing Chest Fly?']},
#  196: {'questions': ['What type of exercise is the Sled Drag classified as?',
#    'What equipment do I need for the Sled Drag exercise?',
#    'Which muscle groups are activated during the Sled Drag?',
#    'Can the Sled Drag be performed walking or running backwards?',
#    'What body part does the Sled Drag primarily target?']},
#  197: {'questions': ['What equipment do I need for the Cable Hammer Curl?',
#    'Which muscles are primarily targeted by the Cable Hammer Curl?',
#    'Can you describe the proper stance for performing a Cable Hammer Curl?',
#    'What grip should I use while curling the handle in the Cable Hammer Curl?',
#    'Is the Cable Hammer Curl considered a strength exercise?']},
#  198: {'questions': ['What is the proper starting position for the Cable Tricep Overhead Extension?',
#    'How do I ensure my arms are fully extended during the exercise?',
#    'Which muscle groups are primarily targeted by the Cable Tricep Overhead Extension?',
#    'What type of exercise is the Cable Tricep Overhead Extension classified as?',
#    'What equipment do I need to perform the Cable Tricep Overhead Extension?']},
#  199: {'questions': ['What is the targeted muscle group when performing the Seated Cable Row?',
#    'What type of exercise is the Seated Cable Row considered?',
#    'How should I position my feet during the Seated Cable Row?',
#    'Can you explain the proper movement for the Seated Cable Row?',
#    'What type of equipment do I need for the Seated Cable Row?']},
#  200: {'questions': ['What is the primary muscle group targeted by the Lying Dumbbell Tricep Extension exercise?',
#    'What equipment do I need to perform the Lying Dumbbell Tricep Extension?',
#    'Can you describe how to properly execute the Lying Dumbbell Tricep Extension?',
#    'Is the Lying Dumbbell Tricep Extension considered a push exercise?',
#    'Which part of the body does the Lying Dumbbell Tricep Extension mainly work on?']},
#  201: {'questions': ['What is the proper way to perform a weighted pull-up?',
#    'Which muscle groups are primarily activated during a weighted pull-up?',
#    'Do I need any specific equipment for weighted pull-ups?',
#    'What part of the body does a weighted pull-up target?',
#    'Can I use dumbbells for the weighted pull-up exercise?']},
#  202: {'questions': ['What is the primary muscle group targeted by the Incline Dumbbell Row exercise?',
#    'How should I position my body when performing the Incline Dumbbell Row?',
#    'What type of equipment do I need for the Incline Dumbbell Row?',
#    'Can you explain the movement I need to perform during the Incline Dumbbell Row?',
#    'Is the Incline Dumbbell Row classified as a push or pull exercise?']},
#  203: {'questions': ['What is the primary muscle group targeted by the Machine Lat Pulldown exercise?',
#    'What type of activity is the Machine Lat Pulldown classified as?',
#    'What specific grip should I use when performing the Machine Lat Pulldown?',
#    'Can you describe the proper starting position for the Machine Lat Pulldown?',
#    'Which body part does the Machine Lat Pulldown primarily focus on?']},
#  204: {'questions': ['What equipment do I need for the One-Arm Cable Row exercise?',
#    'Which muscle groups are primarily worked during the One-Arm Cable Row?',
#    'Can you explain the basic instructions for performing a One-Arm Cable Row?',
#    'Is the One-Arm Cable Row a strength exercise or a cardio exercise?',
#    'Which body part does the One-Arm Cable Row primarily target?']},
#  205: {'questions': ['What equipment do I need to perform the Face Pull exercise?',
#    'Which muscle groups are targeted when doing Face Pulls?',
#    'Can you describe the correct technique for executing a Face Pull?',
#    'What part of the body does the Face Pull primarily work on?',
#    'Is the Face Pull considered a pull or push exercise?']},
#  206: {'questions': ['What is the primary muscle group targeted by the Dumbbell Bench Press?',
#    'What equipment do I need to perform the Dumbbell Bench Press?',
#    'Can you describe the proper starting position for the Dumbbell Bench Press?',
#    'What type of exercise is the Dumbbell Bench Press classified as?',
#    'Which part of the body does the Dumbbell Bench Press mainly engage?']}}

# %%
final_results = []

# %%
for doc_id, questions in results.items():
    for question in questions['questions']:
        final_results.append((doc_id, question))

# %%
df_results = pd.DataFrame(final_results, columns=['id', 'question'])

# %%
df_results.shape
# Out:
# (1035, 2)

# %%
df_results.to_csv('../data/ground-truth-retrieval.csv', index=False)

# %%
# !head ../data/ground-truth-retrieval.csv
# Out:
# id,question
# 0,What is the starting position for push-ups?
# 0,Which muscle groups are targeted during push-ups?
# 0,Do I need any equipment to perform push-ups?
# 0,How do I properly lower my body during a push-up?
# 0,What type of exercise are push-ups classified as?
# 1,What body position should I maintain during squats?
# 1,Which muscle groups are activated when performing squats?
# 1,Do I need any equipment to perform squats?
# 1,How should my feet be positioned while doing squats?
